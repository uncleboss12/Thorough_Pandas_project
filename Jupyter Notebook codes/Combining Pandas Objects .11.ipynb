# %% [markdown]
# ## Introduction

# %% [markdown]
# A wide variety of options are available to combine two or more DataFrames or Series together.
# The append method is the least flexible and only allows for new rows to be appended
# to a DataFrame. The concat method is very versatile and can combine any number of
# DataFrames or Series on either axis. The join method provides fast lookups by aligning
# a column of one DataFrame to the index of others. The merge method provides SQL-like
# capabilities to join two DataFrames together

# %% [markdown]
# ## Appending new rows to DataFrames

# %% [markdown]
# When performing data analysis, it is far more common to create new columns than new rows.
# This is because a new row of data usually represents a new observation, and as an analyst,
# it is typically not your job to continually capture new data. Data capture is usually left to other
# platforms like relational database management systems. Nevertheless, it is a necessary
# feature to know as it will crop up from time to time.
# In this recipe, we will begin by appending rows to a small dataset with the .loc attribute and
# then transition to using the .append method.

# %%
# Read in the names dataset, and output it:

import pandas as pd 
import numpy as np
names = pd.read_csv('C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/names.csv')

# %%
names
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2

# %%
# Let's create a list that contains some new data and 
# use the .loc attribute to set a single row label
# equal to this new data:

new_data_list = ['Aria', 1]

names.loc[4] = new_data_list

# %%
names
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %%
# The .loc attribute uses labels to refer to the rows.
# In this case, the row labels exactly match the 
# integer location. It is possible to append
# more rows with non-integer labels:

names.loc['five'] = ['Zach', 3]

# %%
names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3

# %%
# To be more explicit in associating variables to 
# values, you may use a dictionary. Also, in this step,
# we can dynamically choose the new index label to be 
# the length of the DataFrame
names.loc[len(names)] = {'Name': 'Zach', 'Age': 2}

# %%
names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3
# 6         Zach    2

# %%
len(names)
# Out:
# 7

# %%
# A Series can hold the new data as well and works 
# exactly the same as a dictionary:

names.loc[len(names)] = pd.Series({'Age': '32', 'Name': 'Dean'})

# %%
names
# Out:
#           Name Age
# 0     Cornelia  70
# 1        Abbas  69
# 2     Penelope   4
# 3         Niko   2
# 4         Aria   1
# five      Zach   3
# 6         Zach   2
# 7         Dean  32

# %% [markdown]
# The preceding operations all use the .loc attribute to make changes to the names
# DataFrame in-place. There is no separate copy of the DataFrame that is returned.
# In the next few steps, we will look at the .append method, which does not modify
# the calling DataFrame. Instead, it returns a new copy of the DataFrame with the
# appended row(s). Let's begin with the original names DataFrame and attempt to
# append a row. The first argument to .append must be either another DataFrame,
# Series, dictionary, or a list of these, but not a list like the one in step 2. Let's see
# what happens when we attempt to use a dictionary with .append:

# %%
names = pd.read_csv('C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/names.csv')

# %%
names.append({'Name': 'Aria', 'Age': 1})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JUSTIN~1.O_K\AppData\Local\Temp/ipykernel_2488/1527977704.py in <module>
# ----> 1 names.append({'Name': 'Aria', 'Age': 1})
#
# ~\anaconda31\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8929             if isinstance(other, dict):
#    8930                 if not ignore_index:
# -> 8931                     raise TypeError("Can only append a dict if ignore_index=True")
#    8932                 other = Series(other)
#    8933             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %% [markdown]
# This error message appears to be slightly incorrect. We are passing a dictionary and
# not a Series but nevertheless, it gives us instructions on how to correct it, we need
# to pass the ignore_index=True parameter:

# %%
names.append({'Name': 'Aria', 'Age': 1}, ignore_index=True)
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %% [markdown]
# This works but ignore_index is a sneaky parameter. When set to True, the old
# index will be removed completely and replaced with a RangeIndex from 0 to n-1.
# For instance, let's specify an index for the names DataFrame:

# %%
names.index = ['Canada', 'Canada', 'USA', 'USA']

names
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# USA     Penelope    4
# USA         Niko    2

# %% [markdown]
#  Rerun the code from step 7, and you will get the
#  same result. The original index is completely ignored

# %%
# Let's continue with this names DataFrame with the
# country strings in the index. Let's append a Series 
# that has a name attribute with the .append method:
a = pd.Series({'Name': 'Zach', 'Age': 3}, name=len(names))

# %%
a
# Out:
# Name    Zach
# Age        3
# Name: 4, dtype: object

# %%
names.append(a)
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# USA     Penelope    4
# USA         Niko    2
# 4           Zach    3

# %%
# The .append method is more flexible than the .loc
# attribute. It supports appending multiple rows at the
# same time. One way to accomplish this is by passing 
# in a list of Series:

a1 = pd.Series({'Name': 'Zach', 'Age': 3}, name=len(names))
a2 = pd.Series({'Name': 'Zayd', 'Age': 2}, name='USA')

# %%
names.append([a1, a2])
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# USA     Penelope    4
# USA         Niko    2
# 4           Zach    3
# USA         Zayd    2

# %% [markdown]
# Small DataFrames with only two columns are simple enough to manually write out
# all the column names and values. When they get larger, this process will be quite
# painful. For instance, let's take a look at the 2016 baseball dataset:

# %%
pd.set_option('max_columns', 8, 'max_rows', 15)

bball_16 = pd.read_csv('C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/baseball16.csv')

# %%
bball_16
# Out:
#      playerID  yearID  stint teamID  ...   HBP   SH   SF  GIDP
# 0   altuvjo01    2016      1    HOU  ...   7.0  3.0  7.0  15.0
# 1   bregmal01    2016      1    HOU  ...   0.0  0.0  1.0   1.0
# 2   castrja01    2016      1    HOU  ...   1.0  1.0  0.0   9.0
# 3   correca01    2016      1    HOU  ...   5.0  0.0  3.0  12.0
# 4   gattiev01    2016      1    HOU  ...   4.0  0.0  5.0  12.0
# ..        ...     ...    ...    ...  ...   ...  ...  ...   ...
# 11   reedaj01    2016      1    HOU  ...   0.0  0.0  1.0   1.0
# 12  springe01    2016      1    HOU  ...  11.0  0.0  1.0  12.0
# 13  tuckepr01    2016      1    HOU  ...   2.0  0.0  0.0   2.0
# 14  valbulu01    2016      1    HOU  ...   1.0  3.0  2.0   5.0
# 15  whitety01    2016      1    HOU  ...   2.0  0.0  2.0   6.0
#
# [16 rows x 22 columns]

# %% [markdown]
# This dataset contains 22 columns and it would be easy to mistype a column name or
# forget one altogether if you were manually entering new rows of data. To help protect
# against these mistakes, let's select a single row as a Series and chain the .to_dict
# method to it to get an example row as a dictionary:

# %%
data_dict = bball_16.iloc[0].to_dict()

# %%
data_dict
# Out:
# {'playerID': 'altuvjo01',
#  'yearID': 2016,
#  'stint': 1,
#  'teamID': 'HOU',
#  'lgID': 'AL',
#  'G': 161,
#  'AB': 640,
#  'R': 108,
#  'H': 216,
#  '2B': 42,
#  '3B': 5,
#  'HR': 24,
#  'RBI': 96.0,
#  'SB': 30.0,
#  'CS': 10.0,
#  'BB': 60,
#  'SO': 70.0,
#  'IBB': 11.0,
#  'HBP': 7.0,
#  'SH': 3.0,
#  'SF': 7.0,
#  'GIDP': 15.0}

# %% [markdown]
# Clear the old values with a dictionary comprehension assigning any previous string
# value as an empty string and all others as missing values. This dictionary can now
# serve as a template for any new data you would like to enter:

# %%
new_data_dict = {k: '' if isinstance (v, str) else
                np.nan for k, v in data_dict.items()}

# %%
new_data_dict
# Out:
# {'playerID': '',
#  'yearID': nan,
#  'stint': nan,
#  'teamID': '',
#  'lgID': '',
#  'G': nan,
#  'AB': nan,
#  'R': nan,
#  'H': nan,
#  '2B': nan,
#  '3B': nan,
#  'HR': nan,
#  'RBI': nan,
#  'SB': nan,
#  'CS': nan,
#  'BB': nan,
#  'SO': nan,
#  'IBB': nan,
#  'HBP': nan,
#  'SH': nan,
#  'SF': nan,
#  'GIDP': nan}

# %%
{k: '_' if isinstance(v, str) else
                0 for k, v in data_dict.items()}
# Out:
# {'playerID': '_',
#  'yearID': 0,
#  'stint': 0,
#  'teamID': '_',
#  'lgID': '_',
#  'G': 0,
#  'AB': 0,
#  'R': 0,
#  'H': 0,
#  '2B': 0,
#  '3B': 0,
#  'HR': 0,
#  'RBI': 0,
#  'SB': 0,
#  'CS': 0,
#  'BB': 0,
#  'SO': 0,
#  'IBB': 0,
#  'HBP': 0,
#  'SH': 0,
#  'SF': 0,
#  'GIDP': 0}

# %% [markdown]
# Appending a single row to a DataFrame is a fairly expensive operation and if you find yourself
# writing a loop to append single rows of data to a DataFrame, then you are doing it wrong. Let's
# first create 1,000 rows of new data as a list of Series:

# %%
random_data = []
for i in range(1000):
    d = dict()
    for k, v in data_dict.items():
        if isinstance(v, str):
            d[k] = np.random.choice(list('abcde'))
        else:
            d[k] = np.random.randint(10)
    random_data.append(pd.Series(d, name=i + len(bball_16)))

# %%
random_data
# Out:
# [playerID    d
#  yearID      0
#  stint       3
#  teamID      c
#  lgID        e
#             ..
#  IBB         6
#  HBP         9
#  SH          6
#  SF          8
#  GIDP        9
#  Name: 16, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       0
#  teamID      c
#  lgID        c
#             ..
#  IBB         4
#  HBP         8
#  SH          5
#  SF          0
#  GIDP        8
#  Name: 17, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       4
#  teamID      e
#  lgID        e
#             ..
#  IBB         7
#  HBP         8
#  SH          7
#  SF          8
#  GIDP        2
#  Name: 18, Length: 22, dtype: object,
#  playerID    e
#  yearID      2
#  stint       1
#  teamID      c
#  lgID        b
#             ..
#  IBB         2
#  HBP         2
#  SH          3
#  SF          0
#  GIDP        4
#  Name: 19, Length: 22, dtype: object,
#  playerID    c
#  yearID      4
#  stint       3
#  teamID      e
#  lgID        a
#             ..
#  IBB         4
#  HBP         4
#  SH          7
#  SF          0
#  GIDP        0
#  Name: 20, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       8
#  teamID      b
#  lgID        c
#             ..
#  IBB         7
#  HBP         6
#  SH          1
#  SF          6
#  GIDP        9
#  Name: 21, Length: 22, dtype: object,
#  playerID    b
#  yearID      3
#  stint       8
#  teamID      d
#  lgID        b
#             ..
#  IBB         6
#  HBP         7
#  SH          3
#  SF          0
#  GIDP        5
#  Name: 22, Length: 22, dtype: object,
#  playerID    c
#  yearID      0
#  stint       1
#  teamID      e
#  lgID        d
#             ..
#  IBB         0
#  HBP         4
#  SH          3
#  SF          2
#  GIDP        2
#  Name: 23, Length: 22, dtype: object,
#  playerID    c
#  yearID      3
#  stint       7
#  teamID      b
#  lgID        c
#             ..
#  IBB         4
#  HBP         2
#  SH          2
#  SF          9
#  GIDP        1
#  Name: 24, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       5
#  teamID      a
#  lgID        d
#             ..
#  IBB         5
#  HBP         3
#  SH          1
#  SF          1
#  GIDP        6
#  Name: 25, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       7
#  teamID      d
#  lgID        a
#             ..
#  IBB         4
#  HBP         9
#  SH          6
#  SF          8
#  GIDP        5
#  Name: 26, Length: 22, dtype: object,
#  playerID    b
#  yearID      6
#  stint       3
#  teamID      c
#  lgID        a
#             ..
#  IBB         5
#  HBP         0
#  SH          8
#  SF          3
#  GIDP        5
#  Name: 27, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       8
#  teamID      e
#  lgID        b
#             ..
#  IBB         4
#  HBP         4
#  SH          7
#  SF          1
#  GIDP        3
#  Name: 28, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       5
#  teamID      d
#  lgID        c
#             ..
#  IBB         3
#  HBP         7
#  SH          1
#  SF          7
#  GIDP        6
#  Name: 29, Length: 22, dtype: object,
#  playerID    a
#  yearID      4
#  stint       3
#  teamID      a
#  lgID        a
#             ..
#  IBB         3
#  HBP         0
#  SH          0
#  SF          8
#  GIDP        3
#  Name: 30, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       7
#  teamID      b
#  lgID        d
#             ..
#  IBB         7
#  HBP         9
#  SH          6
#  SF          0
#  GIDP        6
#  Name: 31, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       2
#  teamID      b
#  lgID        b
#             ..
#  IBB         7
#  HBP         6
#  SH          0
#  SF          5
#  GIDP        6
#  Name: 32, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       1
#  teamID      e
#  lgID        a
#             ..
#  IBB         8
#  HBP         2
#  SH          3
#  SF          2
#  GIDP        4
#  Name: 33, Length: 22, dtype: object,
#  playerID    d
#  yearID      5
#  stint       4
#  teamID      b
#  lgID        d
#             ..
#  IBB         5
#  HBP         9
#  SH          5
#  SF          4
#  GIDP        4
#  Name: 34, Length: 22, dtype: object,
#  playerID    d
#  yearID      4
#  stint       3
#  teamID      c
#  lgID        e
#             ..
#  IBB         0
#  HBP         9
#  SH          9
#  SF          1
#  GIDP        3
#  Name: 35, Length: 22, dtype: object,
#  playerID    d
#  yearID      2
#  stint       8
#  teamID      b
#  lgID        c
#             ..
#  IBB         1
#  HBP         4
#  SH          6
#  SF          1
#  GIDP        9
#  Name: 36, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       6
#  teamID      e
#  lgID        d
#             ..
#  IBB         5
#  HBP         3
#  SH          8
#  SF          5
#  GIDP        2
#  Name: 37, Length: 22, dtype: object,
#  playerID    c
#  yearID      9
#  stint       7
#  teamID      a
#  lgID        a
#             ..
#  IBB         6
#  HBP         0
#  SH          3
#  SF          2
#  GIDP        8
#  Name: 38, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       0
#  teamID      a
#  lgID        b
#             ..
#  IBB         3
#  HBP         5
#  SH          6
#  SF          2
#  GIDP        2
#  Name: 39, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       0
#  teamID      c
#  lgID        c
#             ..
#  IBB         0
#  HBP         9
#  SH          5
#  SF          5
#  GIDP        4
#  Name: 40, Length: 22, dtype: object,
#  playerID    a
#  yearID      0
#  stint       0
#  teamID      c
#  lgID        e
#             ..
#  IBB         6
#  HBP         3
#  SH          8
#  SF          1
#  GIDP        5
#  Name: 41, Length: 22, dtype: object,
#  playerID    a
#  yearID      1
#  stint       1
#  teamID      b
#  lgID        d
#             ..
#  IBB         8
#  HBP         4
#  SH          3
#  SF          3
#  GIDP        5
#  Name: 42, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       1
#  teamID      d
#  lgID        b
#             ..
#  IBB         1
#  HBP         8
#  SH          1
#  SF          5
#  GIDP        6
#  Name: 43, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       0
#  teamID      d
#  lgID        d
#             ..
#  IBB         6
#  HBP         8
#  SH          7
#  SF          2
#  GIDP        5
#  Name: 44, Length: 22, dtype: object,
#  playerID    a
#  yearID      0
#  stint       0
#  teamID      d
#  lgID        c
#             ..
#  IBB         6
#  HBP         0
#  SH          6
#  SF          4
#  GIDP        5
#  Name: 45, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       2
#  teamID      a
#  lgID        d
#             ..
#  IBB         4
#  HBP         5
#  SH          1
#  SF          0
#  GIDP        6
#  Name: 46, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       1
#  teamID      b
#  lgID        e
#             ..
#  IBB         1
#  HBP         1
#  SH          2
#  SF          8
#  GIDP        2
#  Name: 47, Length: 22, dtype: object,
#  playerID    b
#  yearID      0
#  stint       9
#  teamID      d
#  lgID        a
#             ..
#  IBB         3
#  HBP         2
#  SH          4
#  SF          4
#  GIDP        3
#  Name: 48, Length: 22, dtype: object,
#  playerID    b
#  yearID      3
#  stint       6
#  teamID      c
#  lgID        c
#             ..
#  IBB         2
#  HBP         9
#  SH          6
#  SF          3
#  GIDP        9
#  Name: 49, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       7
#  teamID      d
#  lgID        c
#             ..
#  IBB         7
#  HBP         5
#  SH          9
#  SF          7
#  GIDP        0
#  Name: 50, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       1
#  teamID      e
#  lgID        b
#             ..
#  IBB         8
#  HBP         5
#  SH          4
#  SF          3
#  GIDP        6
#  Name: 51, Length: 22, dtype: object,
#  playerID    e
#  yearID      4
#  stint       2
#  teamID      d
#  lgID        a
#             ..
#  IBB         8
#  HBP         0
#  SH          3
#  SF          5
#  GIDP        9
#  Name: 52, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       3
#  teamID      b
#  lgID        c
#             ..
#  IBB         4
#  HBP         2
#  SH          8
#  SF          1
#  GIDP        7
#  Name: 53, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       7
#  teamID      c
#  lgID        c
#             ..
#  IBB         9
#  HBP         8
#  SH          3
#  SF          2
#  GIDP        5
#  Name: 54, Length: 22, dtype: object,
#  playerID    d
#  yearID      2
#  stint       1
#  teamID      b
#  lgID        d
#             ..
#  IBB         1
#  HBP         5
#  SH          0
#  SF          7
#  GIDP        4
#  Name: 55, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       7
#  teamID      d
#  lgID        c
#             ..
#  IBB         3
#  HBP         8
#  SH          5
#  SF          1
#  GIDP        0
#  Name: 56, Length: 22, dtype: object,
#  playerID    e
#  yearID      9
#  stint       3
#  teamID      b
#  lgID        c
#             ..
#  IBB         1
#  HBP         8
#  SH          0
#  SF          2
#  GIDP        9
#  Name: 57, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       4
#  teamID      d
#  lgID        c
#             ..
#  IBB         6
#  HBP         5
#  SH          3
#  SF          0
#  GIDP        3
#  Name: 58, Length: 22, dtype: object,
#  playerID    e
#  yearID      5
#  stint       5
#  teamID      c
#  lgID        d
#             ..
#  IBB         3
#  HBP         7
#  SH          8
#  SF          4
#  GIDP        9
#  Name: 59, Length: 22, dtype: object,
#  playerID    e
#  yearID      1
#  stint       8
#  teamID      e
#  lgID        c
#             ..
#  IBB         4
#  HBP         2
#  SH          8
#  SF          6
#  GIDP        2
#  Name: 60, Length: 22, dtype: object,
#  playerID    d
#  yearID      6
#  stint       2
#  teamID      b
#  lgID        c
#             ..
#  IBB         1
#  HBP         9
#  SH          8
#  SF          0
#  GIDP        8
#  Name: 61, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       0
#  teamID      b
#  lgID        a
#             ..
#  IBB         1
#  HBP         9
#  SH          1
#  SF          1
#  GIDP        5
#  Name: 62, Length: 22, dtype: object,
#  playerID    c
#  yearID      4
#  stint       0
#  teamID      a
#  lgID        d
#             ..
#  IBB         3
#  HBP         0
#  SH          9
#  SF          4
#  GIDP        1
#  Name: 63, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       3
#  teamID      c
#  lgID        e
#             ..
#  IBB         8
#  HBP         0
#  SH          0
#  SF          3
#  GIDP        4
#  Name: 64, Length: 22, dtype: object,
#  playerID    d
#  yearID      6
#  stint       6
#  teamID      c
#  lgID        c
#             ..
#  IBB         0
#  HBP         6
#  SH          9
#  SF          9
#  GIDP        9
#  Name: 65, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       8
#  teamID      e
#  lgID        b
#             ..
#  IBB         0
#  HBP         7
#  SH          1
#  SF          0
#  GIDP        8
#  Name: 66, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       9
#  teamID      b
#  lgID        c
#             ..
#  IBB         1
#  HBP         4
#  SH          3
#  SF          7
#  GIDP        3
#  Name: 67, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       3
#  teamID      e
#  lgID        e
#             ..
#  IBB         3
#  HBP         4
#  SH          4
#  SF          1
#  GIDP        3
#  Name: 68, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       7
#  teamID      c
#  lgID        d
#             ..
#  IBB         8
#  HBP         8
#  SH          7
#  SF          6
#  GIDP        1
#  Name: 69, Length: 22, dtype: object,
#  playerID    a
#  yearID      1
#  stint       9
#  teamID      e
#  lgID        a
#             ..
#  IBB         1
#  HBP         2
#  SH          8
#  SF          4
#  GIDP        6
#  Name: 70, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       6
#  teamID      d
#  lgID        d
#             ..
#  IBB         1
#  HBP         5
#  SH          9
#  SF          1
#  GIDP        0
#  Name: 71, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       7
#  teamID      c
#  lgID        e
#             ..
#  IBB         0
#  HBP         8
#  SH          7
#  SF          4
#  GIDP        5
#  Name: 72, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       1
#  teamID      a
#  lgID        c
#             ..
#  IBB         6
#  HBP         7
#  SH          6
#  SF          0
#  GIDP        3
#  Name: 73, Length: 22, dtype: object,
#  playerID    e
#  yearID      1
#  stint       6
#  teamID      a
#  lgID        a
#             ..
#  IBB         6
#  HBP         8
#  SH          6
#  SF          3
#  GIDP        2
#  Name: 74, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       8
#  teamID      b
#  lgID        e
#             ..
#  IBB         1
#  HBP         8
#  SH          3
#  SF          8
#  GIDP        5
#  Name: 75, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       5
#  teamID      d
#  lgID        c
#             ..
#  IBB         9
#  HBP         1
#  SH          9
#  SF          6
#  GIDP        2
#  Name: 76, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       5
#  teamID      b
#  lgID        a
#             ..
#  IBB         7
#  HBP         3
#  SH          0
#  SF          6
#  GIDP        0
#  Name: 77, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       2
#  teamID      d
#  lgID        a
#             ..
#  IBB         5
#  HBP         8
#  SH          8
#  SF          4
#  GIDP        9
#  Name: 78, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       1
#  teamID      a
#  lgID        c
#             ..
#  IBB         9
#  HBP         0
#  SH          0
#  SF          9
#  GIDP        1
#  Name: 79, Length: 22, dtype: object,
#  playerID    d
#  yearID      3
#  stint       4
#  teamID      b
#  lgID        d
#             ..
#  IBB         0
#  HBP         8
#  SH          8
#  SF          9
#  GIDP        2
#  Name: 80, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       1
#  teamID      c
#  lgID        d
#             ..
#  IBB         5
#  HBP         5
#  SH          4
#  SF          0
#  GIDP        2
#  Name: 81, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       1
#  teamID      c
#  lgID        c
#             ..
#  IBB         2
#  HBP         5
#  SH          9
#  SF          8
#  GIDP        4
#  Name: 82, Length: 22, dtype: object,
#  playerID    a
#  yearID      3
#  stint       5
#  teamID      b
#  lgID        c
#             ..
#  IBB         2
#  HBP         7
#  SH          7
#  SF          9
#  GIDP        7
#  Name: 83, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       3
#  teamID      e
#  lgID        a
#             ..
#  IBB         3
#  HBP         9
#  SH          5
#  SF          9
#  GIDP        8
#  Name: 84, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       4
#  teamID      e
#  lgID        d
#             ..
#  IBB         1
#  HBP         0
#  SH          6
#  SF          6
#  GIDP        3
#  Name: 85, Length: 22, dtype: object,
#  playerID    e
#  yearID      2
#  stint       4
#  teamID      b
#  lgID        d
#             ..
#  IBB         1
#  HBP         8
#  SH          9
#  SF          9
#  GIDP        7
#  Name: 86, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       0
#  teamID      b
#  lgID        e
#             ..
#  IBB         4
#  HBP         8
#  SH          2
#  SF          9
#  GIDP        4
#  Name: 87, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       6
#  teamID      d
#  lgID        d
#             ..
#  IBB         7
#  HBP         6
#  SH          7
#  SF          9
#  GIDP        9
#  Name: 88, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       4
#  teamID      a
#  lgID        d
#             ..
#  IBB         0
#  HBP         0
#  SH          5
#  SF          3
#  GIDP        6
#  Name: 89, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       0
#  teamID      c
#  lgID        c
#             ..
#  IBB         2
#  HBP         0
#  SH          1
#  SF          5
#  GIDP        8
#  Name: 90, Length: 22, dtype: object,
#  playerID    c
#  yearID      6
#  stint       6
#  teamID      a
#  lgID        d
#             ..
#  IBB         5
#  HBP         2
#  SH          4
#  SF          9
#  GIDP        5
#  Name: 91, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       2
#  teamID      e
#  lgID        a
#             ..
#  IBB         0
#  HBP         3
#  SH          1
#  SF          9
#  GIDP        6
#  Name: 92, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       6
#  teamID      a
#  lgID        a
#             ..
#  IBB         4
#  HBP         7
#  SH          7
#  SF          4
#  GIDP        9
#  Name: 93, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       3
#  teamID      c
#  lgID        e
#             ..
#  IBB         8
#  HBP         1
#  SH          7
#  SF          6
#  GIDP        9
#  Name: 94, Length: 22, dtype: object,
#  playerID    c
#  yearID      0
#  stint       0
#  teamID      c
#  lgID        b
#             ..
#  IBB         2
#  HBP         6
#  SH          7
#  SF          4
#  GIDP        3
#  Name: 95, Length: 22, dtype: object,
#  playerID    c
#  yearID      1
#  stint       8
#  teamID      b
#  lgID        e
#             ..
#  IBB         3
#  HBP         7
#  SH          2
#  SF          5
#  GIDP        2
#  Name: 96, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       5
#  teamID      a
#  lgID        c
#             ..
#  IBB         8
#  HBP         1
#  SH          8
#  SF          4
#  GIDP        0
#  Name: 97, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       1
#  teamID      c
#  lgID        e
#             ..
#  IBB         2
#  HBP         7
#  SH          5
#  SF          9
#  GIDP        2
#  Name: 98, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       0
#  teamID      a
#  lgID        d
#             ..
#  IBB         6
#  HBP         6
#  SH          2
#  SF          8
#  GIDP        0
#  Name: 99, Length: 22, dtype: object,
#  playerID    c
#  yearID      9
#  stint       1
#  teamID      c
#  lgID        b
#             ..
#  IBB         0
#  HBP         2
#  SH          1
#  SF          5
#  GIDP        7
#  Name: 100, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       4
#  teamID      b
#  lgID        e
#             ..
#  IBB         4
#  HBP         3
#  SH          3
#  SF          9
#  GIDP        3
#  Name: 101, Length: 22, dtype: object,
#  playerID    b
#  yearID      8
#  stint       5
#  teamID      b
#  lgID        d
#             ..
#  IBB         2
#  HBP         3
#  SH          8
#  SF          8
#  GIDP        5
#  Name: 102, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       7
#  teamID      a
#  lgID        d
#             ..
#  IBB         4
#  HBP         5
#  SH          8
#  SF          5
#  GIDP        1
#  Name: 103, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       0
#  teamID      b
#  lgID        d
#             ..
#  IBB         8
#  HBP         2
#  SH          6
#  SF          3
#  GIDP        7
#  Name: 104, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       4
#  teamID      a
#  lgID        b
#             ..
#  IBB         9
#  HBP         2
#  SH          3
#  SF          4
#  GIDP        8
#  Name: 105, Length: 22, dtype: object,
#  playerID    b
#  yearID      3
#  stint       8
#  teamID      b
#  lgID        d
#             ..
#  IBB         3
#  HBP         3
#  SH          4
#  SF          2
#  GIDP        6
#  Name: 106, Length: 22, dtype: object,
#  playerID    c
#  yearID      4
#  stint       6
#  teamID      b
#  lgID        b
#             ..
#  IBB         6
#  HBP         3
#  SH          9
#  SF          3
#  GIDP        5
#  Name: 107, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       6
#  teamID      c
#  lgID        c
#             ..
#  IBB         1
#  HBP         6
#  SH          8
#  SF          1
#  GIDP        1
#  Name: 108, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       3
#  teamID      c
#  lgID        a
#             ..
#  IBB         2
#  HBP         3
#  SH          8
#  SF          0
#  GIDP        6
#  Name: 109, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       9
#  teamID      a
#  lgID        b
#             ..
#  IBB         3
#  HBP         6
#  SH          2
#  SF          2
#  GIDP        7
#  Name: 110, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       4
#  teamID      e
#  lgID        a
#             ..
#  IBB         6
#  HBP         4
#  SH          2
#  SF          4
#  GIDP        0
#  Name: 111, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       1
#  teamID      c
#  lgID        d
#             ..
#  IBB         6
#  HBP         9
#  SH          6
#  SF          6
#  GIDP        5
#  Name: 112, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       8
#  teamID      e
#  lgID        b
#             ..
#  IBB         4
#  HBP         1
#  SH          3
#  SF          9
#  GIDP        1
#  Name: 113, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       8
#  teamID      e
#  lgID        e
#             ..
#  IBB         9
#  HBP         7
#  SH          6
#  SF          4
#  GIDP        0
#  Name: 114, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       0
#  teamID      d
#  lgID        b
#             ..
#  IBB         0
#  HBP         4
#  SH          2
#  SF          5
#  GIDP        8
#  Name: 115, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       7
#  teamID      a
#  lgID        c
#             ..
#  IBB         0
#  HBP         3
#  SH          0
#  SF          1
#  GIDP        7
#  Name: 116, Length: 22, dtype: object,
#  playerID    a
#  yearID      6
#  stint       7
#  teamID      e
#  lgID        b
#             ..
#  IBB         6
#  HBP         0
#  SH          0
#  SF          3
#  GIDP        7
#  Name: 117, Length: 22, dtype: object,
#  playerID    c
#  yearID      0
#  stint       7
#  teamID      e
#  lgID        b
#             ..
#  IBB         7
#  HBP         9
#  SH          9
#  SF          6
#  GIDP        9
#  Name: 118, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       2
#  teamID      e
#  lgID        b
#             ..
#  IBB         8
#  HBP         3
#  SH          7
#  SF          5
#  GIDP        6
#  Name: 119, Length: 22, dtype: object,
#  playerID    c
#  yearID      0
#  stint       2
#  teamID      a
#  lgID        b
#             ..
#  IBB         9
#  HBP         3
#  SH          4
#  SF          4
#  GIDP        8
#  Name: 120, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       5
#  teamID      e
#  lgID        a
#             ..
#  IBB         7
#  HBP         5
#  SH          9
#  SF          7
#  GIDP        4
#  Name: 121, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       0
#  teamID      a
#  lgID        b
#             ..
#  IBB         4
#  HBP         2
#  SH          8
#  SF          4
#  GIDP        9
#  Name: 122, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       2
#  teamID      c
#  lgID        d
#             ..
#  IBB         2
#  HBP         3
#  SH          0
#  SF          5
#  GIDP        7
#  Name: 123, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       3
#  teamID      a
#  lgID        c
#             ..
#  IBB         1
#  HBP         2
#  SH          6
#  SF          5
#  GIDP        6
#  Name: 124, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       4
#  teamID      a
#  lgID        b
#             ..
#  IBB         8
#  HBP         6
#  SH          9
#  SF          9
#  GIDP        3
#  Name: 125, Length: 22, dtype: object,
#  playerID    b
#  yearID      0
#  stint       0
#  teamID      d
#  lgID        c
#             ..
#  IBB         8
#  HBP         6
#  SH          7
#  SF          1
#  GIDP        1
#  Name: 126, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       9
#  teamID      d
#  lgID        b
#             ..
#  IBB         9
#  HBP         4
#  SH          5
#  SF          5
#  GIDP        7
#  Name: 127, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       5
#  teamID      c
#  lgID        b
#             ..
#  IBB         1
#  HBP         8
#  SH          6
#  SF          2
#  GIDP        5
#  Name: 128, Length: 22, dtype: object,
#  playerID    d
#  yearID      4
#  stint       6
#  teamID      e
#  lgID        a
#             ..
#  IBB         3
#  HBP         9
#  SH          2
#  SF          5
#  GIDP        8
#  Name: 129, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       8
#  teamID      c
#  lgID        c
#             ..
#  IBB         5
#  HBP         1
#  SH          6
#  SF          5
#  GIDP        1
#  Name: 130, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       9
#  teamID      a
#  lgID        c
#             ..
#  IBB         7
#  HBP         9
#  SH          7
#  SF          4
#  GIDP        9
#  Name: 131, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       8
#  teamID      c
#  lgID        b
#             ..
#  IBB         6
#  HBP         7
#  SH          1
#  SF          1
#  GIDP        6
#  Name: 132, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       2
#  teamID      d
#  lgID        c
#             ..
#  IBB         9
#  HBP         9
#  SH          0
#  SF          5
#  GIDP        1
#  Name: 133, Length: 22, dtype: object,
#  playerID    b
#  yearID      1
#  stint       7
#  teamID      e
#  lgID        d
#             ..
#  IBB         0
#  HBP         5
#  SH          5
#  SF          4
#  GIDP        1
#  Name: 134, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       7
#  teamID      b
#  lgID        b
#             ..
#  IBB         2
#  HBP         6
#  SH          1
#  SF          7
#  GIDP        2
#  Name: 135, Length: 22, dtype: object,
#  playerID    d
#  yearID      5
#  stint       2
#  teamID      e
#  lgID        b
#             ..
#  IBB         6
#  HBP         4
#  SH          4
#  SF          9
#  GIDP        6
#  Name: 136, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       9
#  teamID      c
#  lgID        e
#             ..
#  IBB         8
#  HBP         0
#  SH          3
#  SF          0
#  GIDP        5
#  Name: 137, Length: 22, dtype: object,
#  playerID    d
#  yearID      3
#  stint       0
#  teamID      e
#  lgID        d
#             ..
#  IBB         0
#  HBP         3
#  SH          6
#  SF          8
#  GIDP        6
#  Name: 138, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       9
#  teamID      b
#  lgID        a
#             ..
#  IBB         9
#  HBP         8
#  SH          8
#  SF          1
#  GIDP        3
#  Name: 139, Length: 22, dtype: object,
#  playerID    b
#  yearID      6
#  stint       0
#  teamID      d
#  lgID        e
#             ..
#  IBB         0
#  HBP         3
#  SH          9
#  SF          5
#  GIDP        0
#  Name: 140, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       7
#  teamID      e
#  lgID        c
#             ..
#  IBB         7
#  HBP         6
#  SH          3
#  SF          7
#  GIDP        2
#  Name: 141, Length: 22, dtype: object,
#  playerID    e
#  yearID      4
#  stint       3
#  teamID      c
#  lgID        c
#             ..
#  IBB         7
#  HBP         7
#  SH          3
#  SF          1
#  GIDP        4
#  Name: 142, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       1
#  teamID      c
#  lgID        a
#             ..
#  IBB         0
#  HBP         2
#  SH          3
#  SF          1
#  GIDP        1
#  Name: 143, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       1
#  teamID      e
#  lgID        a
#             ..
#  IBB         8
#  HBP         8
#  SH          0
#  SF          3
#  GIDP        1
#  Name: 144, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       5
#  teamID      e
#  lgID        e
#             ..
#  IBB         8
#  HBP         0
#  SH          5
#  SF          8
#  GIDP        4
#  Name: 145, Length: 22, dtype: object,
#  playerID    e
#  yearID      1
#  stint       4
#  teamID      e
#  lgID        d
#             ..
#  IBB         5
#  HBP         1
#  SH          1
#  SF          1
#  GIDP        8
#  Name: 146, Length: 22, dtype: object,
#  playerID    e
#  yearID      9
#  stint       8
#  teamID      c
#  lgID        c
#             ..
#  IBB         3
#  HBP         7
#  SH          2
#  SF          0
#  GIDP        7
#  Name: 147, Length: 22, dtype: object,
#  playerID    c
#  yearID      3
#  stint       9
#  teamID      d
#  lgID        e
#             ..
#  IBB         0
#  HBP         4
#  SH          1
#  SF          0
#  GIDP        3
#  Name: 148, Length: 22, dtype: object,
#  playerID    d
#  yearID      4
#  stint       6
#  teamID      b
#  lgID        e
#             ..
#  IBB         0
#  HBP         5
#  SH          7
#  SF          7
#  GIDP        1
#  Name: 149, Length: 22, dtype: object,
#  playerID    c
#  yearID      9
#  stint       2
#  teamID      b
#  lgID        a
#             ..
#  IBB         2
#  HBP         0
#  SH          9
#  SF          5
#  GIDP        4
#  Name: 150, Length: 22, dtype: object,
#  playerID    c
#  yearID      3
#  stint       6
#  teamID      d
#  lgID        e
#             ..
#  IBB         8
#  HBP         6
#  SH          4
#  SF          0
#  GIDP        7
#  Name: 151, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       7
#  teamID      e
#  lgID        c
#             ..
#  IBB         4
#  HBP         1
#  SH          6
#  SF          9
#  GIDP        9
#  Name: 152, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       6
#  teamID      c
#  lgID        d
#             ..
#  IBB         2
#  HBP         8
#  SH          0
#  SF          4
#  GIDP        3
#  Name: 153, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       0
#  teamID      d
#  lgID        a
#             ..
#  IBB         2
#  HBP         0
#  SH          7
#  SF          5
#  GIDP        3
#  Name: 154, Length: 22, dtype: object,
#  playerID    e
#  yearID      2
#  stint       8
#  teamID      c
#  lgID        c
#             ..
#  IBB         3
#  HBP         6
#  SH          8
#  SF          2
#  GIDP        1
#  Name: 155, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       2
#  teamID      d
#  lgID        c
#             ..
#  IBB         3
#  HBP         9
#  SH          6
#  SF          0
#  GIDP        9
#  Name: 156, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       0
#  teamID      e
#  lgID        a
#             ..
#  IBB         7
#  HBP         1
#  SH          0
#  SF          5
#  GIDP        2
#  Name: 157, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       7
#  teamID      e
#  lgID        a
#             ..
#  IBB         6
#  HBP         5
#  SH          3
#  SF          5
#  GIDP        7
#  Name: 158, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       3
#  teamID      c
#  lgID        d
#             ..
#  IBB         3
#  HBP         5
#  SH          2
#  SF          3
#  GIDP        4
#  Name: 159, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       9
#  teamID      a
#  lgID        a
#             ..
#  IBB         3
#  HBP         3
#  SH          4
#  SF          3
#  GIDP        8
#  Name: 160, Length: 22, dtype: object,
#  playerID    d
#  yearID      2
#  stint       3
#  teamID      a
#  lgID        d
#             ..
#  IBB         6
#  HBP         4
#  SH          7
#  SF          8
#  GIDP        6
#  Name: 161, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       3
#  teamID      a
#  lgID        e
#             ..
#  IBB         2
#  HBP         1
#  SH          3
#  SF          6
#  GIDP        1
#  Name: 162, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       0
#  teamID      a
#  lgID        b
#             ..
#  IBB         1
#  HBP         2
#  SH          9
#  SF          2
#  GIDP        2
#  Name: 163, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       8
#  teamID      a
#  lgID        d
#             ..
#  IBB         7
#  HBP         4
#  SH          0
#  SF          5
#  GIDP        1
#  Name: 164, Length: 22, dtype: object,
#  playerID    e
#  yearID      1
#  stint       7
#  teamID      d
#  lgID        e
#             ..
#  IBB         8
#  HBP         4
#  SH          9
#  SF          1
#  GIDP        8
#  Name: 165, Length: 22, dtype: object,
#  playerID    c
#  yearID      4
#  stint       3
#  teamID      e
#  lgID        d
#             ..
#  IBB         4
#  HBP         1
#  SH          9
#  SF          3
#  GIDP        6
#  Name: 166, Length: 22, dtype: object,
#  playerID    d
#  yearID      7
#  stint       8
#  teamID      c
#  lgID        d
#             ..
#  IBB         5
#  HBP         5
#  SH          7
#  SF          9
#  GIDP        8
#  Name: 167, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       5
#  teamID      a
#  lgID        e
#             ..
#  IBB         8
#  HBP         1
#  SH          7
#  SF          0
#  GIDP        9
#  Name: 168, Length: 22, dtype: object,
#  playerID    b
#  yearID      0
#  stint       0
#  teamID      a
#  lgID        e
#             ..
#  IBB         8
#  HBP         5
#  SH          6
#  SF          8
#  GIDP        5
#  Name: 169, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       2
#  teamID      c
#  lgID        b
#             ..
#  IBB         6
#  HBP         1
#  SH          5
#  SF          9
#  GIDP        4
#  Name: 170, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       8
#  teamID      a
#  lgID        c
#             ..
#  IBB         0
#  HBP         9
#  SH          9
#  SF          1
#  GIDP        7
#  Name: 171, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       9
#  teamID      e
#  lgID        c
#             ..
#  IBB         8
#  HBP         0
#  SH          9
#  SF          8
#  GIDP        0
#  Name: 172, Length: 22, dtype: object,
#  playerID    d
#  yearID      6
#  stint       7
#  teamID      a
#  lgID        d
#             ..
#  IBB         1
#  HBP         1
#  SH          4
#  SF          4
#  GIDP        7
#  Name: 173, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       2
#  teamID      a
#  lgID        c
#             ..
#  IBB         3
#  HBP         4
#  SH          4
#  SF          6
#  GIDP        8
#  Name: 174, Length: 22, dtype: object,
#  playerID    d
#  yearID      6
#  stint       8
#  teamID      c
#  lgID        c
#             ..
#  IBB         3
#  HBP         4
#  SH          4
#  SF          0
#  GIDP        1
#  Name: 175, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       3
#  teamID      c
#  lgID        e
#             ..
#  IBB         1
#  HBP         5
#  SH          1
#  SF          1
#  GIDP        7
#  Name: 176, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       2
#  teamID      b
#  lgID        b
#             ..
#  IBB         8
#  HBP         4
#  SH          0
#  SF          8
#  GIDP        0
#  Name: 177, Length: 22, dtype: object,
#  playerID    b
#  yearID      1
#  stint       9
#  teamID      c
#  lgID        a
#             ..
#  IBB         3
#  HBP         8
#  SH          1
#  SF          4
#  GIDP        4
#  Name: 178, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       4
#  teamID      e
#  lgID        e
#             ..
#  IBB         5
#  HBP         5
#  SH          9
#  SF          6
#  GIDP        8
#  Name: 179, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       4
#  teamID      c
#  lgID        c
#             ..
#  IBB         6
#  HBP         3
#  SH          5
#  SF          2
#  GIDP        7
#  Name: 180, Length: 22, dtype: object,
#  playerID    c
#  yearID      3
#  stint       2
#  teamID      e
#  lgID        c
#             ..
#  IBB         6
#  HBP         1
#  SH          9
#  SF          8
#  GIDP        2
#  Name: 181, Length: 22, dtype: object,
#  playerID    b
#  yearID      8
#  stint       0
#  teamID      a
#  lgID        b
#             ..
#  IBB         9
#  HBP         1
#  SH          2
#  SF          6
#  GIDP        0
#  Name: 182, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       8
#  teamID      c
#  lgID        e
#             ..
#  IBB         1
#  HBP         8
#  SH          7
#  SF          9
#  GIDP        1
#  Name: 183, Length: 22, dtype: object,
#  playerID    c
#  yearID      6
#  stint       6
#  teamID      e
#  lgID        d
#             ..
#  IBB         4
#  HBP         9
#  SH          7
#  SF          1
#  GIDP        0
#  Name: 184, Length: 22, dtype: object,
#  playerID    d
#  yearID      3
#  stint       2
#  teamID      c
#  lgID        a
#             ..
#  IBB         1
#  HBP         0
#  SH          5
#  SF          0
#  GIDP        7
#  Name: 185, Length: 22, dtype: object,
#  playerID    a
#  yearID      4
#  stint       2
#  teamID      c
#  lgID        a
#             ..
#  IBB         9
#  HBP         9
#  SH          4
#  SF          9
#  GIDP        2
#  Name: 186, Length: 22, dtype: object,
#  playerID    c
#  yearID      1
#  stint       5
#  teamID      b
#  lgID        a
#             ..
#  IBB         8
#  HBP         0
#  SH          5
#  SF          0
#  GIDP        4
#  Name: 187, Length: 22, dtype: object,
#  playerID    e
#  yearID      2
#  stint       3
#  teamID      a
#  lgID        d
#             ..
#  IBB         2
#  HBP         8
#  SH          3
#  SF          5
#  GIDP        4
#  Name: 188, Length: 22, dtype: object,
#  playerID    e
#  yearID      9
#  stint       9
#  teamID      a
#  lgID        b
#             ..
#  IBB         5
#  HBP         7
#  SH          5
#  SF          7
#  GIDP        5
#  Name: 189, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       1
#  teamID      d
#  lgID        e
#             ..
#  IBB         8
#  HBP         5
#  SH          1
#  SF          5
#  GIDP        3
#  Name: 190, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       5
#  teamID      a
#  lgID        d
#             ..
#  IBB         1
#  HBP         9
#  SH          0
#  SF          8
#  GIDP        0
#  Name: 191, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       0
#  teamID      e
#  lgID        c
#             ..
#  IBB         9
#  HBP         0
#  SH          9
#  SF          5
#  GIDP        1
#  Name: 192, Length: 22, dtype: object,
#  playerID    a
#  yearID      6
#  stint       5
#  teamID      e
#  lgID        a
#             ..
#  IBB         9
#  HBP         0
#  SH          9
#  SF          9
#  GIDP        8
#  Name: 193, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       8
#  teamID      a
#  lgID        a
#             ..
#  IBB         9
#  HBP         8
#  SH          3
#  SF          2
#  GIDP        6
#  Name: 194, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       5
#  teamID      c
#  lgID        c
#             ..
#  IBB         5
#  HBP         5
#  SH          8
#  SF          4
#  GIDP        2
#  Name: 195, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       1
#  teamID      b
#  lgID        a
#             ..
#  IBB         2
#  HBP         3
#  SH          9
#  SF          1
#  GIDP        8
#  Name: 196, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       0
#  teamID      e
#  lgID        e
#             ..
#  IBB         4
#  HBP         0
#  SH          8
#  SF          4
#  GIDP        9
#  Name: 197, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       2
#  teamID      b
#  lgID        c
#             ..
#  IBB         2
#  HBP         3
#  SH          0
#  SF          4
#  GIDP        7
#  Name: 198, Length: 22, dtype: object,
#  playerID    b
#  yearID      1
#  stint       9
#  teamID      e
#  lgID        d
#             ..
#  IBB         2
#  HBP         0
#  SH          9
#  SF          9
#  GIDP        4
#  Name: 199, Length: 22, dtype: object,
#  playerID    c
#  yearID      9
#  stint       0
#  teamID      b
#  lgID        b
#             ..
#  IBB         9
#  HBP         6
#  SH          6
#  SF          3
#  GIDP        2
#  Name: 200, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       6
#  teamID      e
#  lgID        a
#             ..
#  IBB         3
#  HBP         8
#  SH          7
#  SF          0
#  GIDP        7
#  Name: 201, Length: 22, dtype: object,
#  playerID    b
#  yearID      8
#  stint       4
#  teamID      d
#  lgID        e
#             ..
#  IBB         5
#  HBP         0
#  SH          5
#  SF          7
#  GIDP        7
#  Name: 202, Length: 22, dtype: object,
#  playerID    e
#  yearID      2
#  stint       6
#  teamID      e
#  lgID        a
#             ..
#  IBB         4
#  HBP         2
#  SH          8
#  SF          2
#  GIDP        8
#  Name: 203, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       0
#  teamID      e
#  lgID        d
#             ..
#  IBB         2
#  HBP         6
#  SH          1
#  SF          8
#  GIDP        0
#  Name: 204, Length: 22, dtype: object,
#  playerID    a
#  yearID      0
#  stint       2
#  teamID      c
#  lgID        a
#             ..
#  IBB         3
#  HBP         0
#  SH          6
#  SF          6
#  GIDP        9
#  Name: 205, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       9
#  teamID      b
#  lgID        e
#             ..
#  IBB         0
#  HBP         0
#  SH          8
#  SF          6
#  GIDP        5
#  Name: 206, Length: 22, dtype: object,
#  playerID    b
#  yearID      6
#  stint       3
#  teamID      b
#  lgID        d
#             ..
#  IBB         3
#  HBP         4
#  SH          2
#  SF          0
#  GIDP        2
#  Name: 207, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       8
#  teamID      c
#  lgID        d
#             ..
#  IBB         7
#  HBP         4
#  SH          1
#  SF          1
#  GIDP        4
#  Name: 208, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       1
#  teamID      d
#  lgID        a
#             ..
#  IBB         2
#  HBP         3
#  SH          2
#  SF          7
#  GIDP        5
#  Name: 209, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       3
#  teamID      b
#  lgID        e
#             ..
#  IBB         9
#  HBP         1
#  SH          6
#  SF          8
#  GIDP        9
#  Name: 210, Length: 22, dtype: object,
#  playerID    a
#  yearID      4
#  stint       6
#  teamID      e
#  lgID        c
#             ..
#  IBB         3
#  HBP         0
#  SH          3
#  SF          1
#  GIDP        6
#  Name: 211, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       0
#  teamID      d
#  lgID        b
#             ..
#  IBB         5
#  HBP         3
#  SH          1
#  SF          2
#  GIDP        0
#  Name: 212, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       7
#  teamID      d
#  lgID        c
#             ..
#  IBB         6
#  HBP         9
#  SH          2
#  SF          9
#  GIDP        6
#  Name: 213, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       0
#  teamID      c
#  lgID        e
#             ..
#  IBB         6
#  HBP         1
#  SH          7
#  SF          6
#  GIDP        6
#  Name: 214, Length: 22, dtype: object,
#  playerID    c
#  yearID      1
#  stint       2
#  teamID      d
#  lgID        a
#             ..
#  IBB         5
#  HBP         0
#  SH          4
#  SF          0
#  GIDP        6
#  Name: 215, Length: 22, dtype: object,
#  playerID    c
#  yearID      9
#  stint       6
#  teamID      b
#  lgID        a
#             ..
#  IBB         0
#  HBP         8
#  SH          7
#  SF          9
#  GIDP        7
#  Name: 216, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       5
#  teamID      b
#  lgID        c
#             ..
#  IBB         6
#  HBP         9
#  SH          9
#  SF          9
#  GIDP        3
#  Name: 217, Length: 22, dtype: object,
#  playerID    c
#  yearID      1
#  stint       2
#  teamID      b
#  lgID        b
#             ..
#  IBB         0
#  HBP         1
#  SH          7
#  SF          3
#  GIDP        6
#  Name: 218, Length: 22, dtype: object,
#  playerID    d
#  yearID      7
#  stint       3
#  teamID      d
#  lgID        d
#             ..
#  IBB         9
#  HBP         2
#  SH          1
#  SF          8
#  GIDP        5
#  Name: 219, Length: 22, dtype: object,
#  playerID    d
#  yearID      4
#  stint       2
#  teamID      d
#  lgID        d
#             ..
#  IBB         9
#  HBP         4
#  SH          4
#  SF          2
#  GIDP        1
#  Name: 220, Length: 22, dtype: object,
#  playerID    c
#  yearID      6
#  stint       7
#  teamID      d
#  lgID        c
#             ..
#  IBB         5
#  HBP         9
#  SH          9
#  SF          6
#  GIDP        3
#  Name: 221, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       1
#  teamID      a
#  lgID        d
#             ..
#  IBB         6
#  HBP         8
#  SH          9
#  SF          0
#  GIDP        7
#  Name: 222, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       6
#  teamID      e
#  lgID        e
#             ..
#  IBB         2
#  HBP         2
#  SH          1
#  SF          0
#  GIDP        9
#  Name: 223, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       6
#  teamID      e
#  lgID        e
#             ..
#  IBB         8
#  HBP         0
#  SH          5
#  SF          1
#  GIDP        1
#  Name: 224, Length: 22, dtype: object,
#  playerID    b
#  yearID      3
#  stint       3
#  teamID      b
#  lgID        b
#             ..
#  IBB         8
#  HBP         4
#  SH          9
#  SF          0
#  GIDP        3
#  Name: 225, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       0
#  teamID      b
#  lgID        d
#             ..
#  IBB         5
#  HBP         4
#  SH          1
#  SF          8
#  GIDP        7
#  Name: 226, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       6
#  teamID      c
#  lgID        e
#             ..
#  IBB         6
#  HBP         2
#  SH          0
#  SF          3
#  GIDP        3
#  Name: 227, Length: 22, dtype: object,
#  playerID    a
#  yearID      1
#  stint       8
#  teamID      e
#  lgID        e
#             ..
#  IBB         3
#  HBP         5
#  SH          9
#  SF          1
#  GIDP        6
#  Name: 228, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       5
#  teamID      c
#  lgID        e
#             ..
#  IBB         1
#  HBP         0
#  SH          2
#  SF          0
#  GIDP        7
#  Name: 229, Length: 22, dtype: object,
#  playerID    b
#  yearID      6
#  stint       2
#  teamID      c
#  lgID        e
#             ..
#  IBB         0
#  HBP         0
#  SH          8
#  SF          5
#  GIDP        9
#  Name: 230, Length: 22, dtype: object,
#  playerID    a
#  yearID      3
#  stint       9
#  teamID      a
#  lgID        e
#             ..
#  IBB         4
#  HBP         3
#  SH          1
#  SF          9
#  GIDP        0
#  Name: 231, Length: 22, dtype: object,
#  playerID    d
#  yearID      6
#  stint       8
#  teamID      b
#  lgID        b
#             ..
#  IBB         6
#  HBP         7
#  SH          9
#  SF          0
#  GIDP        2
#  Name: 232, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       8
#  teamID      b
#  lgID        b
#             ..
#  IBB         9
#  HBP         5
#  SH          0
#  SF          4
#  GIDP        4
#  Name: 233, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       9
#  teamID      c
#  lgID        b
#             ..
#  IBB         5
#  HBP         2
#  SH          9
#  SF          8
#  GIDP        4
#  Name: 234, Length: 22, dtype: object,
#  playerID    d
#  yearID      4
#  stint       8
#  teamID      a
#  lgID        b
#             ..
#  IBB         1
#  HBP         1
#  SH          7
#  SF          0
#  GIDP        2
#  Name: 235, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       8
#  teamID      c
#  lgID        e
#             ..
#  IBB         6
#  HBP         1
#  SH          9
#  SF          7
#  GIDP        3
#  Name: 236, Length: 22, dtype: object,
#  playerID    a
#  yearID      6
#  stint       7
#  teamID      e
#  lgID        d
#             ..
#  IBB         0
#  HBP         8
#  SH          4
#  SF          6
#  GIDP        2
#  Name: 237, Length: 22, dtype: object,
#  playerID    e
#  yearID      9
#  stint       5
#  teamID      c
#  lgID        e
#             ..
#  IBB         1
#  HBP         3
#  SH          1
#  SF          2
#  GIDP        7
#  Name: 238, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       8
#  teamID      d
#  lgID        d
#             ..
#  IBB         2
#  HBP         3
#  SH          5
#  SF          5
#  GIDP        6
#  Name: 239, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       2
#  teamID      a
#  lgID        b
#             ..
#  IBB         1
#  HBP         6
#  SH          6
#  SF          5
#  GIDP        1
#  Name: 240, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       9
#  teamID      c
#  lgID        d
#             ..
#  IBB         7
#  HBP         5
#  SH          4
#  SF          6
#  GIDP        8
#  Name: 241, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       3
#  teamID      d
#  lgID        c
#             ..
#  IBB         9
#  HBP         3
#  SH          7
#  SF          0
#  GIDP        3
#  Name: 242, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       6
#  teamID      c
#  lgID        a
#             ..
#  IBB         9
#  HBP         6
#  SH          6
#  SF          8
#  GIDP        7
#  Name: 243, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       0
#  teamID      e
#  lgID        a
#             ..
#  IBB         0
#  HBP         8
#  SH          3
#  SF          9
#  GIDP        7
#  Name: 244, Length: 22, dtype: object,
#  playerID    d
#  yearID      5
#  stint       9
#  teamID      b
#  lgID        e
#             ..
#  IBB         2
#  HBP         0
#  SH          0
#  SF          9
#  GIDP        0
#  Name: 245, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       1
#  teamID      e
#  lgID        d
#             ..
#  IBB         4
#  HBP         8
#  SH          2
#  SF          0
#  GIDP        1
#  Name: 246, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       9
#  teamID      d
#  lgID        c
#             ..
#  IBB         5
#  HBP         9
#  SH          3
#  SF          6
#  GIDP        6
#  Name: 247, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       6
#  teamID      a
#  lgID        d
#             ..
#  IBB         5
#  HBP         1
#  SH          5
#  SF          0
#  GIDP        0
#  Name: 248, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       6
#  teamID      d
#  lgID        a
#             ..
#  IBB         2
#  HBP         8
#  SH          0
#  SF          8
#  GIDP        9
#  Name: 249, Length: 22, dtype: object,
#  playerID    c
#  yearID      0
#  stint       2
#  teamID      a
#  lgID        a
#             ..
#  IBB         4
#  HBP         4
#  SH          8
#  SF          3
#  GIDP        1
#  Name: 250, Length: 22, dtype: object,
#  playerID    c
#  yearID      3
#  stint       6
#  teamID      e
#  lgID        c
#             ..
#  IBB         9
#  HBP         7
#  SH          5
# ...
#  SF          5
#  GIDP        1
#  Name: 937, Length: 22, dtype: object,
#  playerID    d
#  yearID      2
#  stint       6
#  teamID      c
#  lgID        e
#             ..
#  IBB         4
#  HBP         6
#  SH          5
#  SF          9
#  GIDP        0
#  Name: 938, Length: 22, dtype: object,
#  playerID    e
#  yearID      4
#  stint       5
#  teamID      a
#  lgID        a
#             ..
#  IBB         1
#  HBP         0
#  SH          7
#  SF          0
#  GIDP        1
#  Name: 939, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       0
#  teamID      e
#  lgID        e
#             ..
#  IBB         8
#  HBP         5
#  SH          6
#  SF          5
#  GIDP        4
#  Name: 940, Length: 22, dtype: object,
#  playerID    e
#  yearID      3
#  stint       1
#  teamID      e
#  lgID        b
#             ..
#  IBB         8
#  HBP         9
#  SH          8
#  SF          6
#  GIDP        0
#  Name: 941, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       0
#  teamID      c
#  lgID        c
#             ..
#  IBB         5
#  HBP         6
#  SH          4
#  SF          6
#  GIDP        1
#  Name: 942, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       6
#  teamID      b
#  lgID        a
#             ..
#  IBB         5
#  HBP         3
#  SH          4
#  SF          4
#  GIDP        3
#  Name: 943, Length: 22, dtype: object,
#  playerID    d
#  yearID      0
#  stint       7
#  teamID      c
#  lgID        c
#             ..
#  IBB         3
#  HBP         5
#  SH          1
#  SF          6
#  GIDP        4
#  Name: 944, Length: 22, dtype: object,
#  playerID    b
#  yearID      5
#  stint       7
#  teamID      d
#  lgID        c
#             ..
#  IBB         5
#  HBP         3
#  SH          7
#  SF          2
#  GIDP        3
#  Name: 945, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       2
#  teamID      b
#  lgID        c
#             ..
#  IBB         6
#  HBP         8
#  SH          9
#  SF          0
#  GIDP        6
#  Name: 946, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       2
#  teamID      c
#  lgID        c
#             ..
#  IBB         9
#  HBP         3
#  SH          7
#  SF          4
#  GIDP        2
#  Name: 947, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       0
#  teamID      e
#  lgID        e
#             ..
#  IBB         8
#  HBP         1
#  SH          3
#  SF          0
#  GIDP        8
#  Name: 948, Length: 22, dtype: object,
#  playerID    d
#  yearID      8
#  stint       5
#  teamID      e
#  lgID        b
#             ..
#  IBB         9
#  HBP         2
#  SH          8
#  SF          0
#  GIDP        5
#  Name: 949, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       6
#  teamID      c
#  lgID        b
#             ..
#  IBB         5
#  HBP         5
#  SH          6
#  SF          1
#  GIDP        8
#  Name: 950, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       1
#  teamID      a
#  lgID        d
#             ..
#  IBB         3
#  HBP         4
#  SH          1
#  SF          0
#  GIDP        9
#  Name: 951, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       0
#  teamID      c
#  lgID        b
#             ..
#  IBB         2
#  HBP         7
#  SH          7
#  SF          7
#  GIDP        6
#  Name: 952, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       3
#  teamID      d
#  lgID        a
#             ..
#  IBB         3
#  HBP         7
#  SH          3
#  SF          2
#  GIDP        5
#  Name: 953, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       1
#  teamID      e
#  lgID        d
#             ..
#  IBB         6
#  HBP         8
#  SH          4
#  SF          2
#  GIDP        0
#  Name: 954, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       6
#  teamID      c
#  lgID        d
#             ..
#  IBB         3
#  HBP         6
#  SH          8
#  SF          7
#  GIDP        1
#  Name: 955, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       8
#  teamID      c
#  lgID        c
#             ..
#  IBB         1
#  HBP         0
#  SH          2
#  SF          5
#  GIDP        8
#  Name: 956, Length: 22, dtype: object,
#  playerID    b
#  yearID      4
#  stint       6
#  teamID      d
#  lgID        d
#             ..
#  IBB         6
#  HBP         7
#  SH          3
#  SF          8
#  GIDP        6
#  Name: 957, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       6
#  teamID      d
#  lgID        c
#             ..
#  IBB         0
#  HBP         0
#  SH          6
#  SF          4
#  GIDP        2
#  Name: 958, Length: 22, dtype: object,
#  playerID    c
#  yearID      1
#  stint       4
#  teamID      d
#  lgID        e
#             ..
#  IBB         7
#  HBP         9
#  SH          0
#  SF          5
#  GIDP        7
#  Name: 959, Length: 22, dtype: object,
#  playerID    c
#  yearID      1
#  stint       8
#  teamID      e
#  lgID        b
#             ..
#  IBB         0
#  HBP         3
#  SH          3
#  SF          8
#  GIDP        4
#  Name: 960, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       4
#  teamID      b
#  lgID        d
#             ..
#  IBB         9
#  HBP         9
#  SH          3
#  SF          8
#  GIDP        9
#  Name: 961, Length: 22, dtype: object,
#  playerID    b
#  yearID      1
#  stint       0
#  teamID      b
#  lgID        b
#             ..
#  IBB         7
#  HBP         6
#  SH          1
#  SF          5
#  GIDP        2
#  Name: 962, Length: 22, dtype: object,
#  playerID    c
#  yearID      3
#  stint       3
#  teamID      d
#  lgID        a
#             ..
#  IBB         5
#  HBP         8
#  SH          5
#  SF          0
#  GIDP        8
#  Name: 963, Length: 22, dtype: object,
#  playerID    a
#  yearID      1
#  stint       7
#  teamID      d
#  lgID        a
#             ..
#  IBB         1
#  HBP         7
#  SH          7
#  SF          2
#  GIDP        1
#  Name: 964, Length: 22, dtype: object,
#  playerID    c
#  yearID      4
#  stint       9
#  teamID      d
#  lgID        c
#             ..
#  IBB         4
#  HBP         2
#  SH          4
#  SF          6
#  GIDP        2
#  Name: 965, Length: 22, dtype: object,
#  playerID    b
#  yearID      1
#  stint       0
#  teamID      c
#  lgID        c
#             ..
#  IBB         9
#  HBP         2
#  SH          6
#  SF          0
#  GIDP        4
#  Name: 966, Length: 22, dtype: object,
#  playerID    b
#  yearID      8
#  stint       5
#  teamID      c
#  lgID        b
#             ..
#  IBB         3
#  HBP         0
#  SH          7
#  SF          5
#  GIDP        3
#  Name: 967, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       6
#  teamID      a
#  lgID        a
#             ..
#  IBB         3
#  HBP         0
#  SH          9
#  SF          6
#  GIDP        7
#  Name: 968, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       2
#  teamID      d
#  lgID        d
#             ..
#  IBB         9
#  HBP         0
#  SH          6
#  SF          2
#  GIDP        1
#  Name: 969, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       8
#  teamID      c
#  lgID        b
#             ..
#  IBB         5
#  HBP         2
#  SH          6
#  SF          6
#  GIDP        7
#  Name: 970, Length: 22, dtype: object,
#  playerID    d
#  yearID      2
#  stint       6
#  teamID      e
#  lgID        c
#             ..
#  IBB         0
#  HBP         8
#  SH          5
#  SF          4
#  GIDP        2
#  Name: 971, Length: 22, dtype: object,
#  playerID    e
#  yearID      6
#  stint       6
#  teamID      e
#  lgID        b
#             ..
#  IBB         3
#  HBP         4
#  SH          2
#  SF          7
#  GIDP        4
#  Name: 972, Length: 22, dtype: object,
#  playerID    e
#  yearID      1
#  stint       2
#  teamID      a
#  lgID        e
#             ..
#  IBB         3
#  HBP         9
#  SH          7
#  SF          1
#  GIDP        8
#  Name: 973, Length: 22, dtype: object,
#  playerID    c
#  yearID      2
#  stint       1
#  teamID      c
#  lgID        c
#             ..
#  IBB         0
#  HBP         2
#  SH          9
#  SF          6
#  GIDP        4
#  Name: 974, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       7
#  teamID      c
#  lgID        c
#             ..
#  IBB         2
#  HBP         0
#  SH          8
#  SF          5
#  GIDP        8
#  Name: 975, Length: 22, dtype: object,
#  playerID    a
#  yearID      9
#  stint       7
#  teamID      c
#  lgID        c
#             ..
#  IBB         2
#  HBP         9
#  SH          6
#  SF          8
#  GIDP        5
#  Name: 976, Length: 22, dtype: object,
#  playerID    a
#  yearID      3
#  stint       1
#  teamID      a
#  lgID        c
#             ..
#  IBB         8
#  HBP         7
#  SH          0
#  SF          6
#  GIDP        3
#  Name: 977, Length: 22, dtype: object,
#  playerID    b
#  yearID      7
#  stint       6
#  teamID      b
#  lgID        c
#             ..
#  IBB         2
#  HBP         3
#  SH          1
#  SF          9
#  GIDP        5
#  Name: 978, Length: 22, dtype: object,
#  playerID    c
#  yearID      7
#  stint       8
#  teamID      c
#  lgID        d
#             ..
#  IBB         1
#  HBP         2
#  SH          9
#  SF          3
#  GIDP        2
#  Name: 979, Length: 22, dtype: object,
#  playerID    d
#  yearID      5
#  stint       5
#  teamID      d
#  lgID        e
#             ..
#  IBB         0
#  HBP         5
#  SH          3
#  SF          3
#  GIDP        7
#  Name: 980, Length: 22, dtype: object,
#  playerID    a
#  yearID      4
#  stint       6
#  teamID      a
#  lgID        c
#             ..
#  IBB         0
#  HBP         8
#  SH          3
#  SF          7
#  GIDP        3
#  Name: 981, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       9
#  teamID      e
#  lgID        b
#             ..
#  IBB         2
#  HBP         5
#  SH          9
#  SF          8
#  GIDP        8
#  Name: 982, Length: 22, dtype: object,
#  playerID    d
#  yearID      9
#  stint       1
#  teamID      d
#  lgID        d
#             ..
#  IBB         8
#  HBP         4
#  SH          2
#  SF          9
#  GIDP        6
#  Name: 983, Length: 22, dtype: object,
#  playerID    a
#  yearID      2
#  stint       7
#  teamID      a
#  lgID        e
#             ..
#  IBB         0
#  HBP         9
#  SH          5
#  SF          1
#  GIDP        4
#  Name: 984, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       4
#  teamID      a
#  lgID        d
#             ..
#  IBB         1
#  HBP         4
#  SH          0
#  SF          2
#  GIDP        4
#  Name: 985, Length: 22, dtype: object,
#  playerID    d
#  yearID      5
#  stint       7
#  teamID      a
#  lgID        d
#             ..
#  IBB         6
#  HBP         1
#  SH          2
#  SF          3
#  GIDP        8
#  Name: 986, Length: 22, dtype: object,
#  playerID    a
#  yearID      5
#  stint       0
#  teamID      c
#  lgID        c
#             ..
#  IBB         0
#  HBP         9
#  SH          0
#  SF          8
#  GIDP        4
#  Name: 987, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       9
#  teamID      d
#  lgID        a
#             ..
#  IBB         4
#  HBP         9
#  SH          8
#  SF          5
#  GIDP        5
#  Name: 988, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       1
#  teamID      c
#  lgID        b
#             ..
#  IBB         6
#  HBP         4
#  SH          5
#  SF          7
#  GIDP        1
#  Name: 989, Length: 22, dtype: object,
#  playerID    e
#  yearID      4
#  stint       8
#  teamID      e
#  lgID        b
#             ..
#  IBB         2
#  HBP         4
#  SH          0
#  SF          4
#  GIDP        6
#  Name: 990, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       7
#  teamID      d
#  lgID        d
#             ..
#  IBB         0
#  HBP         6
#  SH          5
#  SF          0
#  GIDP        0
#  Name: 991, Length: 22, dtype: object,
#  playerID    a
#  yearID      4
#  stint       8
#  teamID      a
#  lgID        b
#             ..
#  IBB         8
#  HBP         2
#  SH          9
#  SF          1
#  GIDP        2
#  Name: 992, Length: 22, dtype: object,
#  playerID    e
#  yearID      7
#  stint       5
#  teamID      b
#  lgID        e
#             ..
#  IBB         5
#  HBP         8
#  SH          4
#  SF          7
#  GIDP        3
#  Name: 993, Length: 22, dtype: object,
#  playerID    e
#  yearID      4
#  stint       6
#  teamID      e
#  lgID        d
#             ..
#  IBB         4
#  HBP         4
#  SH          9
#  SF          9
#  GIDP        3
#  Name: 994, Length: 22, dtype: object,
#  playerID    d
#  yearID      3
#  stint       9
#  teamID      c
#  lgID        e
#             ..
#  IBB         2
#  HBP         1
#  SH          7
#  SF          9
#  GIDP        6
#  Name: 995, Length: 22, dtype: object,
#  playerID    b
#  yearID      6
#  stint       3
#  teamID      c
#  lgID        b
#             ..
#  IBB         3
#  HBP         6
#  SH          8
#  SF          0
#  GIDP        1
#  Name: 996, Length: 22, dtype: object,
#  playerID    b
#  yearID      0
#  stint       8
#  teamID      b
#  lgID        b
#             ..
#  IBB         8
#  HBP         5
#  SH          0
#  SF          2
#  GIDP        5
#  Name: 997, Length: 22, dtype: object,
#  playerID    a
#  yearID      8
#  stint       1
#  teamID      b
#  lgID        c
#             ..
#  IBB         7
#  HBP         8
#  SH          6
#  SF          0
#  GIDP        3
#  Name: 998, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       7
#  teamID      c
#  lgID        e
#             ..
#  IBB         8
#  HBP         9
#  SH          6
#  SF          9
#  GIDP        6
#  Name: 999, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       3
#  teamID      d
#  lgID        d
#             ..
#  IBB         6
#  HBP         0
#  SH          6
#  SF          1
#  GIDP        0
#  Name: 1000, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       3
#  teamID      c
#  lgID        c
#             ..
#  IBB         6
#  HBP         3
#  SH          8
#  SF          0
#  GIDP        5
#  Name: 1001, Length: 22, dtype: object,
#  playerID    c
#  yearID      5
#  stint       7
#  teamID      a
#  lgID        d
#             ..
#  IBB         0
#  HBP         8
#  SH          1
#  SF          7
#  GIDP        6
#  Name: 1002, Length: 22, dtype: object,
#  playerID    c
#  yearID      8
#  stint       5
#  teamID      b
#  lgID        c
#             ..
#  IBB         1
#  HBP         2
#  SH          7
#  SF          7
#  GIDP        6
#  Name: 1003, Length: 22, dtype: object,
#  playerID    e
#  yearID      8
#  stint       4
#  teamID      a
#  lgID        a
#             ..
#  IBB         9
#  HBP         0
#  SH          1
#  SF          7
#  GIDP        8
#  Name: 1004, Length: 22, dtype: object,
#  playerID    e
#  yearID      9
#  stint       1
#  teamID      d
#  lgID        e
#             ..
#  IBB         9
#  HBP         3
#  SH          0
#  SF          0
#  GIDP        3
#  Name: 1005, Length: 22, dtype: object,
#  playerID    b
#  yearID      2
#  stint       7
#  teamID      d
#  lgID        b
#             ..
#  IBB         7
#  HBP         8
#  SH          2
#  SF          5
#  GIDP        8
#  Name: 1006, Length: 22, dtype: object,
#  playerID    b
#  yearID      9
#  stint       5
#  teamID      a
#  lgID        c
#             ..
#  IBB         3
#  HBP         9
#  SH          9
#  SF          0
#  GIDP        6
#  Name: 1007, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       4
#  teamID      b
#  lgID        b
#             ..
#  IBB         5
#  HBP         7
#  SH          4
#  SF          0
#  GIDP        9
#  Name: 1008, Length: 22, dtype: object,
#  playerID    a
#  yearID      4
#  stint       3
#  teamID      a
#  lgID        c
#             ..
#  IBB         5
#  HBP         8
#  SH          8
#  SF          2
#  GIDP        0
#  Name: 1009, Length: 22, dtype: object,
#  playerID    a
#  yearID      0
#  stint       2
#  teamID      b
#  lgID        d
#             ..
#  IBB         9
#  HBP         1
#  SH          2
#  SF          5
#  GIDP        7
#  Name: 1010, Length: 22, dtype: object,
#  playerID    c
#  yearID      0
#  stint       6
#  teamID      d
#  lgID        e
#             ..
#  IBB         1
#  HBP         0
#  SH          2
#  SF          8
#  GIDP        7
#  Name: 1011, Length: 22, dtype: object,
#  playerID    d
#  yearID      1
#  stint       5
#  teamID      a
#  lgID        e
#             ..
#  IBB         5
#  HBP         8
#  SH          6
#  SF          0
#  GIDP        8
#  Name: 1012, Length: 22, dtype: object,
#  playerID    e
#  yearID      0
#  stint       1
#  teamID      c
#  lgID        d
#             ..
#  IBB         4
#  HBP         1
#  SH          0
#  SF          4
#  GIDP        6
#  Name: 1013, Length: 22, dtype: object,
#  playerID    a
#  yearID      7
#  stint       6
#  teamID      d
#  lgID        d
#             ..
#  IBB         1
#  HBP         8
#  SH          8
#  SF          3
#  GIDP        0
#  Name: 1014, Length: 22, dtype: object,
#  playerID    d
#  yearID      3
#  stint       2
#  teamID      e
#  lgID        a
#             ..
#  IBB         0
#  HBP         5
#  SH          8
#  SF          2
#  GIDP        0
#  Name: 1015, Length: 22, dtype: object]

# %% [markdown]
#  Let's time how long it takes to loop through each
# item making one append at a time:

# %%
# %%timeit
bball_16_copy = bball_16.copy()
for row in random_data:
    bball_16_copy = bball_16_copy.append(row)
# Out:
# 4.83 s ± 155 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# That took nearly five seconds for only 1,000 rows. If we instead pass in the entire list of Series,
# we get an enormous speed increase:

# %%
# %%timeit
bball_16_copy = bball_16.copy()
bball_16_copy = bball_16.append(random_data)
# Out:
# 91 ms ± 4.43 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# If you pass in a list of Series objects, the time has been reduced to under one-tenth of a second. Internally, pandas converts the list of Series to a single DataFrame and then
# appends the data.

# %% [markdown]
# ## Concatenating multiple DataFrames together

# %% [markdown]
# The concat function enables concatenating two or more DataFrames (or Series) together,
# both vertically and horizontally. As per usual, when dealing with multiple pandas objects
# simultaneously, concatenation doesn't happen haphazardly but aligns each object by
# their index.

# %%
stocks_2016 = pd.read_csv('C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/stocks_2016.csv')
stocks_2017 = pd.read_csv('C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/stocks_2017.csv')

# %%
stocks_2016
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
stocks_2017
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      50  120   140
# 1     GE     100   30    40
# 2    IBM      87   75    95
# 3    SLB      20   55    85
# 4    TXN     500   15    23
# 5   TSLA     100  100   300

# %%
# Place all the stock datasets into a single list, and 
# then call the concat function to concatenate them
# together along the default axis (0):
s_list = [stocks_2016, stocks_2017]

pd.concat(s_list)
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70
# 0   AAPL      50  120   140
# 1     GE     100   30    40
# 2    IBM      87   75    95
# 3    SLB      20   55    85
# 4    TXN     500   15    23
# 5   TSLA     100  100   300

# %% [markdown]
# By default, the concat function concatenates DataFrames vertically, one on
# top of the other. One issue with the preceding DataFrame is that there is no way
# to identify the year of each row. The concat function allows each piece of the
# resulting DataFrame to be labeled with the keys parameter. This label will appear
# in the outermost index level of the concatenated frame and force the creation of a
# MultiIndex. Also, the names parameter has the ability to rename each index level
# for clarity:

# %%
pd.concat(s_list, keys=['2016', '2017'], 
         names=['Year', 'Symbol'], )
# Out:
#             Symbol  Shares  Low  High
# Year Symbol
# 2016 0        AAPL      80   95   110
#      1        TSLA      50   80   130
#      2         WMT      40   55    70
# 2017 0        AAPL      50  120   140
#      1          GE     100   30    40
#      2         IBM      87   75    95
#      3         SLB      20   55    85
#      4         TXN     500   15    23
#      5        TSLA     100  100   300

# %%
# It is also possible to concatenate horizontally by
# changing the axis parameter to columns or 1:
pd.concat(s_list, keys=['2016', 2017], 
         axis='columns', names=['Year', 'Symbol']
         )
# Out:
# Year     2016                       2017
# Symbol Symbol Shares   Low   High Symbol Shares  Low High
# 0        AAPL   80.0  95.0  110.0   AAPL     50  120  140
# 1        TSLA   50.0  80.0  130.0     GE    100   30   40
# 2         WMT   40.0  55.0   70.0    IBM     87   75   95
# 3         NaN    NaN   NaN    NaN    SLB     20   55   85
# 4         NaN    NaN   NaN    NaN    TXN    500   15   23
# 5         NaN    NaN   NaN    NaN   TSLA    100  100  300

# %% [markdown]
# Notice that missing values appear whenever a stock symbol is present in one year
# but not the other. The concat function, by default, uses an outer join, keeping all
# rows from each DataFrame in the list. However, it gives us an option to keep only
# rows that have the same index values in both DataFrames. This is referred to as
# an inner join. We set the join parameter to inner to change the behavior:

# %%
pd.concat(s_list, keys=['2016', 2017], join='inner',
         axis='columns', names=['Year', 'Symbol']
         )
# Out:
# Year     2016                   2017
# Symbol Symbol Shares Low High Symbol Shares  Low High
# 0        AAPL     80  95  110   AAPL     50  120  140
# 1        TSLA     50  80  130     GE    100   30   40
# 2         WMT     40  55   70    IBM     87   75   95

# %% [markdown]
# The .append method is a heavily watered-down version of concat that can only append new
# rows to a DataFrame. Internally, .append just calls the concat function. For instance, step 2
# from this recipe may be duplicated with the following:

# %%
stocks_2016.append(stocks_2017)
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70
# 0   AAPL      50  120   140
# 1     GE     100   30    40
# 2    IBM      87   75    95
# 3    SLB      20   55    85
# 4    TXN     500   15    23
# 5   TSLA     100  100   300

# %% [markdown]
# ## Understanding the difference between concat, join, and merge

# %% [markdown]
# The .merge and .join DataFrame (and not Series) methods and the concat function all
# provide very similar functionality to combine multiple pandas objects together. As they are
# so similar and they can replicate each other in certain situations, it can get very confusing
# regarding when and how to use them correctly.

# %% [markdown]
# To help clarify their differences, take a look at the following outline:
#
#     .concat:
#
#  A pandas function
#
#  Combines two or more pandas objects vertically or horizontally
#
#  Aligns only on the index
#
#  Errors whenever a duplicate appears in the index
#
#  Defaults to outer join with the option for inner join
#
#     .join:
#
#  A DataFrame method
#
#  Combines two or more pandas objects horizontally
#
#  Aligns the calling DataFrame's column(s) or index with the other object's index (and
# not the columns)
#
#  Handles duplicate values on the joining columns/index by performing a Cartesian
# product
#
#
#  Defaults to left join with options for inner, outer, and right
#
#     .merge:
#
#  A DataFrame method
#
#  Combines exactly two DataFrames horizontally
#
#  Aligns the calling DataFrame's column(s) or index with the other DataFrame's
# column(s) or index
#
#  Handles duplicate values on the joining columns or index by performing a cartesian
# product
#
#  Defaults to inner join with options for left, outer, and right
#
# In this recipe, we will combine DataFrames. The first situation is simpler with concat while
# the second is simpler with .merge.

# %%
# Let's read in stock data for 2016, 2017, and 2018
# into a list of DataFrames using a loop instead of
# three different calls to the read_csv function:

years = 2016, 2017, 2018
stock_tables  = [pd.read_csv(f'C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/stocks_{year}.csv', index_col='Symbol') for year in years]

# %%
stocks_2016, stocks_2017, stocks_2018 = stock_tables

# %%
stocks_2016
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70

# %%
stocks_2017
# Out:
#         Shares  Low  High
# Symbol
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
stocks_2018
# Out:
#         Shares  Low  High
# Symbol
# AAPL        40  135   170
# AMZN         8  900  1125
# TSLA        50  220   400

# %%
# The concat function is the only pandas method that is
# able to combine DataFrames vertically. Let's do this
# by passing it the list stock_tables:

pd.concat(stock_tables, keys=['2016', 2017, 2018], names=['Year'])
# Out:
#              Shares  Low  High
# Year Symbol
# 2016 AAPL        80   95   110
#      TSLA        50   80   130
#      WMT         40   55    70
# 2017 AAPL        50  120   140
#      GE         100   30    40
#      IBM         87   75    95
#      SLB         20   55    85
#      TXN        500   15    23
#      TSLA       100  100   300
# 2018 AAPL        40  135   170
#      AMZN         8  900  1125
#      TSLA        50  220   400

# %%
# It can also combine DataFrames horizontally by 
# changing the axis parameter to columns:
pd.concat(dict(zip(years, stock_tables)), axis='columns')
# Out:
#          2016                2017  ...          2018
#        Shares   Low   High Shares  ...   High Shares    Low    High
# Symbol                             ...
# AAPL     80.0  95.0  110.0   50.0  ...  140.0   40.0  135.0   170.0
# TSLA     50.0  80.0  130.0  100.0  ...  300.0   50.0  220.0   400.0
# WMT      40.0  55.0   70.0    NaN  ...    NaN    NaN    NaN     NaN
# GE        NaN   NaN    NaN  100.0  ...   40.0    NaN    NaN     NaN
# IBM       NaN   NaN    NaN   87.0  ...   95.0    NaN    NaN     NaN
# SLB       NaN   NaN    NaN   20.0  ...   85.0    NaN    NaN     NaN
# TXN       NaN   NaN    NaN  500.0  ...   23.0    NaN    NaN     NaN
# AMZN      NaN   NaN    NaN    NaN  ...    NaN    8.0  900.0  1125.0
#
# [8 rows x 9 columns]

# %%
e = ['abel', 'shade', 'mike', 'edu']
f = [2, 4, 5, 7]
dict(zip(e, f))
# Out:
# {'abel': 2, 'shade': 4, 'mike': 5, 'edu': 7}

# %% [markdown]
# Now that we have started combining DataFrames horizontally, we can use the .join
# and .merge methods to replicate this functionality of concat. Here, we use the
# .join method to combine the stock_2016 and stock_2017 DataFrames. By
# default, the DataFrames align on their index. If any of the columns have the same
# names, then you must supply a value to the lsuffix or rsuffix parameters to
# distinguish them in the result:

# %%
stocks_2016.join(stocks_2017, lsuffix='_2016', rsuffix='_2017', how='outer')
# Out:
#         Shares_2016  Low_2016  High_2016  Shares_2017  Low_2017  High_2017
# Symbol
# AAPL           80.0      95.0      110.0         50.0     120.0      140.0
# GE              NaN       NaN        NaN        100.0      30.0       40.0
# IBM             NaN       NaN        NaN         87.0      75.0       95.0
# SLB             NaN       NaN        NaN         20.0      55.0       85.0
# TSLA           50.0      80.0      130.0        100.0     100.0      300.0
# TXN             NaN       NaN        NaN        500.0      15.0       23.0
# WMT            40.0      55.0       70.0          NaN       NaN        NaN

# %%
# To replicate the output of the concat function from
# step 3, we can pass a list of DataFrames to
# the .join method:

other = [stocks_2017.add_suffix('_2017'),
        stocks_2018.add_suffix('_2018')]

# %%
stocks_2016.add_suffix('_2016').join(other, how='outer')
# Out:
#         Shares_2016  Low_2016  High_2016  Shares_2017  ...  High_2017  \
# Symbol                                                 ...
# AAPL           80.0      95.0      110.0         50.0  ...      140.0
# TSLA           50.0      80.0      130.0        100.0  ...      300.0
# WMT            40.0      55.0       70.0          NaN  ...        NaN
# GE              NaN       NaN        NaN        100.0  ...       40.0
# IBM             NaN       NaN        NaN         87.0  ...       95.0
# SLB             NaN       NaN        NaN         20.0  ...       85.0
# TXN             NaN       NaN        NaN        500.0  ...       23.0
# AMZN            NaN       NaN        NaN          NaN  ...        NaN
#
#         Shares_2018  Low_2018  High_2018
# Symbol
# AAPL           40.0     135.0      170.0
# TSLA           50.0     220.0      400.0
# WMT             NaN       NaN        NaN
# GE              NaN       NaN        NaN
# IBM             NaN       NaN        NaN
# SLB             NaN       NaN        NaN
# TXN             NaN       NaN        NaN
# AMZN            8.0     900.0     1125.0
#
# [8 rows x 9 columns]

# %%
# Let's check whether they are equal:
stock_join = stocks_2016.add_suffix('_2016').join(other, how='outer')

# %%
stock_concat = (
    pd.concat(
        dict(zip(years, stock_tables)), axis='columns')
    .swaplevel(axis=1)
    .pipe(lambda df_: 
          df_.set_axis(df_.columns.to_flat_index(), axis=1)
    .rename(lambda label:  
           "_".join([str(x) for x in label]), axis=1))
    )

# %%
stock_join.equals(stock_concat)
# Out:
# True

# %% [markdown]
# Now, let's turn to the .merge method that, unlike concat and .join, can only
# combine two DataFrames together. By default, .merge attempts to align the values
# in the columns that have the same name for each of the DataFrames. However, you
# can choose to have it align on the index by setting the Boolean parameters left_
# index and right_index to True. Let's merge the 2016 and 2017 stock data
# together

# %%
stocks_2016.merge(stocks_2017, left_index=True, right_index=True,)
# Out:
#         Shares_x  Low_x  High_x  Shares_y  Low_y  High_y
# Symbol
# AAPL          80     95     110        50    120     140
# TSLA          50     80     130       100    100     300

# %% [markdown]
# By default, .merge uses an inner join and automatically supplies suffixes for
# identically named columns. Let's change to an outer join and then perform another
# outer join of the 2018 data to replicate the behavior of concat. Note that in pandas
# 1.0, the merge index will be sorted and the concat version won't be:

# %%
stock_merge = (stocks_2016
               .merge(stocks_2017, left_index=True,
                     right_index=True, how='outer',
                     suffixes=('_2016', '_2017'))
               .merge(stocks_2018.add_suffix('_2018'), 
                     left_index=True, right_index=True,
                     how='outer')
              )

# %%
stock_merge
# Out:
#         Shares_2016  Low_2016  High_2016  Shares_2017  ...  High_2017  \
# Symbol                                                 ...
# AAPL           80.0      95.0      110.0         50.0  ...      140.0
# AMZN            NaN       NaN        NaN          NaN  ...        NaN
# GE              NaN       NaN        NaN        100.0  ...       40.0
# IBM             NaN       NaN        NaN         87.0  ...       95.0
# SLB             NaN       NaN        NaN         20.0  ...       85.0
# TSLA           50.0      80.0      130.0        100.0  ...      300.0
# TXN             NaN       NaN        NaN        500.0  ...       23.0
# WMT            40.0      55.0       70.0          NaN  ...        NaN
#
#         Shares_2018  Low_2018  High_2018
# Symbol
# AAPL           40.0     135.0      170.0
# AMZN            8.0     900.0     1125.0
# GE              NaN       NaN        NaN
# IBM             NaN       NaN        NaN
# SLB             NaN       NaN        NaN
# TSLA           50.0     220.0      400.0
# TXN             NaN       NaN        NaN
# WMT             NaN       NaN        NaN
#
# [8 rows x 9 columns]

# %%
stock_concat.sort_index().equals(stock_merge)
# Out:
# True

# %% [markdown]
# Now let's turn our comparison to datasets where we are interested in aligning
# together the values of columns and not the index or column labels themselves. The
# .merge method is built for this situation. Let's take a look at two new small datasets,
# food_prices and food_transactions:

# %%
names = ['prices', 'transactions']
food_tables = [pd.read_csv(f'C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/food_{name}.csv') for name in names]

# %%
food_tables
# Out:
# [     item store  price  Date
#  0    pear     A   0.99  2017
#  1    pear     B   1.99  2017
#  2   peach     A   2.99  2017
#  3   peach     B   3.49  2017
#  4  banana     A   0.39  2017
#  5  banana     B   0.49  2017
#  6   steak     A   5.99  2017
#  7   steak     B   6.99  2017
#  8   steak     B   4.99  2015,
#     custid     item store  quantity
#  0       1     pear     A         5
#  1       1   banana     A        10
#  2       2    steak     B         3
#  3       2     pear     B         1
#  4       2    peach     B         2
#  5       2    steak     B         1
#  6       2  coconut     B         4]

# %%
food_prices, food_transactions = food_tables

# %%
food_prices
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017
# 6   steak     A   5.99  2017
# 7   steak     B   6.99  2017
# 8   steak     B   4.99  2015

# %%
food_transactions
# Out:
#    custid     item store  quantity
# 0       1     pear     A         5
# 1       1   banana     A        10
# 2       2    steak     B         3
# 3       2     pear     B         1
# 4       2    peach     B         2
# 5       2    steak     B         1
# 6       2  coconut     B         4

# %%
# If we wanted to find the total amount of each
# transaction, we would need to join these tables on
# the item and store columns:

food_transactions.merge(food_prices, on=['item', 'store'])
# Out:
#    custid    item store  quantity  price  Date
# 0       1    pear     A         5   0.99  2017
# 1       1  banana     A        10   0.39  2017
# 2       2   steak     B         3   6.99  2017
# 3       2   steak     B         3   4.99  2015
# 4       2   steak     B         1   6.99  2017
# 5       2   steak     B         1   4.99  2015
# 6       2    pear     B         1   1.99  2017
# 7       2   peach     B         2   3.49  2017

# %% [markdown]
# The price is now aligned correctly with its corresponding item and store, but there is
# a problem. Customer 2 has a total of four steak items. As the steak item appears
# twice in each table for store B, a Cartesian product takes place between them,
# resulting in four rows. Also, notice that the item, coconut, is missing because there
# was no corresponding price for it. Let's fix both of these issues:

# %%
food_transactions.merge(food_prices.query('Date == 2017'), how='left')
# Out:
#    custid     item store  quantity  price    Date
# 0       1     pear     A         5   0.99  2017.0
# 1       1   banana     A        10   0.39  2017.0
# 2       2    steak     B         3   6.99  2017.0
# 3       2     pear     B         1   1.99  2017.0
# 4       2    peach     B         2   3.49  2017.0
# 5       2    steak     B         1   6.99  2017.0
# 6       2  coconut     B         4    NaN     NaN

# %%
# We can replicate this with the .join method,
# but we must first put the joining columns of the 
# food_prices DataFrame into the index:
food_prices_join = food_prices.query('Date == 2017') \
                   .set_index(['item', 'store'])

# %%
food_prices_join
# Out:
#               price  Date
# item   store
# pear   A       0.99  2017
#        B       1.99  2017
# peach  A       2.99  2017
#        B       3.49  2017
# banana A       0.39  2017
#        B       0.49  2017
# steak  A       5.99  2017
#        B       6.99  2017

# %% [markdown]
# The .join method only aligns with the index of the passed DataFrame but can use
# the index or the columns of the calling DataFrame. To use columns for alignment
# on the calling DataFrame, you will need to pass them to the on parameter:

# %%
food_transactions.join(food_prices_join, on=['item', 'store'])
# Out:
#    custid     item store  quantity  price    Date
# 0       1     pear     A         5   0.99  2017.0
# 1       1   banana     A        10   0.39  2017.0
# 2       2    steak     B         3   6.99  2017.0
# 3       2     pear     B         1   1.99  2017.0
# 4       2    peach     B         2   3.49  2017.0
# 5       2    steak     B         1   6.99  2017.0
# 6       2  coconut     B         4    NaN     NaN

# %% [markdown]
# The output matches the result from step 11. To replicate this with the concat
# function, you would need to put the item and store columns into the index of
# both DataFrames. However, in this particular case, an error would be produced as
# a duplicate index value occurs in at least one of the DataFrames (with item steak
# and store B):

# %%
pd.concat([food_transactions.set_index(['item', 'store']),
    food_prices.set_index(['item', 'store'])],
     axis='columns')
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# C:\Users\JUSTIN~1.O_K\AppData\Local\Temp/ipykernel_2488/2199268552.py in <module>
# ----> 1 pd.concat([food_transactions.set_index(['item', 'store']),
#       2     food_prices.set_index(['item', 'store'])],
#       3      axis='columns')
#
# ~\anaconda31\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda31\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~\anaconda31\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     526                     obj_labels = obj.axes[1 - ax]
#     527                     if not new_labels.equals(obj_labels):
# --> 528                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     529
#     530                 mgrs_indexers.append((obj._mgr, indexers))
#
# ~\anaconda31\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3440
#    3441         if not self._index_as_unique:
# -> 3442             raise InvalidIndexError(self._requires_unique_msg)
#    3443
#    3444         if not self._should_compare(target) and not is_interval_dtype(self.dtype):
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %% [markdown]
# It is possible to read all files from a particular directory into DataFrames without knowing their
# names. Python provides a few ways to iterate through directories, with the glob module being
# a popular choice. The gas prices directory contains five different CSV files, each having
# weekly prices of a particular grade of gas beginning from 2007. Each file has just two columns
# – the date for the week and the price. This is a perfect situation to iterate through all the files,
# read them into DataFrames, and combine them all together with the concat function.
# The glob module has the glob function, which takes a single parameter – the location of the
# directory you would like to iterate through as a string. To get all the files in the directory, use
# the string *. In this example, ''*.csv' returns only files that end in .csv. The result from
# the glob function is a list of string filenames, which can be passed to the read_csv function:

# %%
import glob
df_list = []

for filename in glob.glob('C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/gas prices/*.csv'):
    df_list.append(pd.read_csv(filename, index_col='Week', parse_dates=['Week']))

# %%
gas = pd.concat(df_list, axis='columns')

# %%
gas
# Out:
#             All Grades  Diesel  Midgrade  Premium  Regular
# Week
# 2017-09-25       2.701   2.788     2.859    3.105    2.583
# 2017-09-18       2.750   2.791     2.906    3.151    2.634
# 2017-09-11       2.800   2.802     2.953    3.197    2.685
# 2017-09-04       2.794   2.758     2.946    3.191    2.679
# 2017-08-28       2.513   2.605     2.668    2.901    2.399
# ...                ...     ...       ...      ...      ...
# 2007-01-29       2.213   2.413     2.277    2.381    2.165
# 2007-01-22       2.216   2.430     2.285    2.391    2.165
# 2007-01-15       2.280   2.463     2.347    2.453    2.229
# 2007-01-08       2.354   2.537     2.418    2.523    2.306
# 2007-01-01       2.382   2.580     2.442    2.547    2.334
#
# [561 rows x 5 columns]

# %% [markdown]
# ## Connecting to SQL databases

# %%
# Before we can begin reading tables from the chinook
# database, we need to set up our SQLAlchemy engine:
pd.set_option('max_columns', 4, 'max_rows', 20)
from sqlalchemy import create_engine
engine = create_engine('sqlite:///C:/Users/justine.o_kobo360/Desktop/Pandas Workbook/Pandas CookBook 1.x/Data files/chinook.db')

# %% [markdown]
# We can now step back into the world of pandas and remain there for the rest of
# the recipe. Let's complete a command and read in the tracks table with the
# read_sql_table function. The name of the table is the first argument and the
# SQLAlchemy engine is the second:

# %%
tracks = pd.read_sql_table('tracks', engine)

# %%
tracks
# Out:
#       TrackId  ... UnitPrice
# 0           1  ...      0.99
# 1           2  ...      0.99
# 2           3  ...      0.99
# 3           4  ...      0.99
# 4           5  ...      0.99
# ...       ...  ...       ...
# 3498     3499  ...      0.99
# 3499     3500  ...      0.99
# 3500     3501  ...      0.99
# 3501     3502  ...      0.99
# 3502     3503  ...      0.99
#
# [3503 rows x 9 columns]

# %% [markdown]
# For the rest of the recipe, we will answer a couple of different specific queries with
# help from the database diagram. To begin, let's find the average length of song per
# genre

# %%
(pd.read_sql_table('genres', engine)
 .merge(tracks[['GenreId', 'Milliseconds']],
        on='GenreId', how='left'
       ).drop('GenreId', axis=1)
)
# Out:
#            Name  Milliseconds
# 0          Rock        343719
# 1          Rock        342562
# 2          Rock        230619
# 3          Rock        252051
# 4          Rock        375418
# ...         ...           ...
# 3498  Classical        286741
# 3499  Classical        139200
# 3500  Classical         66639
# 3501  Classical        221331
# 3502      Opera        174813
#
# [3503 rows x 2 columns]

# %% [markdown]
# Now we can easily find the average length of each song per genre. To help ease
# interpretation, we convert the Milliseconds column to the timedelta data type:

# %%
(pd.read_sql_table('genres', engine)
 .merge(tracks[['GenreId', 'Milliseconds']],
        on='GenreId', how='left'
       ).drop('GenreId', axis=1)
 .groupby('Name')
 ['Milliseconds']
 .mean()
 .pipe(lambda s_: pd.to_datetime(s_, unit='ms')
      .rename('Length'))
 .dt.floor('s')
 .sort_values()

)
# Out:
# Name
# Rock And Roll      1970-01-01 00:02:14
# Opera              1970-01-01 00:02:54
# Hip Hop/Rap        1970-01-01 00:02:58
# Easy Listening     1970-01-01 00:03:09
# Bossa Nova         1970-01-01 00:03:39
#                            ...
# Comedy             1970-01-01 00:26:25
# TV Shows           1970-01-01 00:35:45
# Drama              1970-01-01 00:42:55
# Science Fiction    1970-01-01 00:43:45
# Sci Fi & Fantasy   1970-01-01 00:48:31
# Name: Length, Length: 25, dtype: datetime64[ns]

# %% [markdown]
# Now let's find the total amount spent per customer. We will need the customers,
# invoices, and invoice_items tables all connected to each other

# %%
cust = pd.read_sql_table('customers', engine,
                        columns=['CustomerId', 'FirstName',
                                'LastName'])
invoice = pd.read_sql_table('invoices', engine,
                        columns=['InvoiceId','CustomerId'])
invoice_items = pd.read_sql_table('invoice_items', engine, 
                                 columns=['InvoiceId', 'UnitPrice', 'Quantity'])

# %%
(cust
 .merge(invoice, on='CustomerId')
 .merge(invoice_items, on='InvoiceId')
)
# Out:
#       CustomerId FirstName  ... UnitPrice  Quantity
# 0              1      Luís  ...      1.99         1
# 1              1      Luís  ...      1.99         1
# 2              1      Luís  ...      0.99         1
# 3              1      Luís  ...      0.99         1
# 4              1      Luís  ...      0.99         1
# ...          ...       ...  ...       ...       ...
# 2235          59      Puja  ...      0.99         1
# 2236          59      Puja  ...      0.99         1
# 2237          59      Puja  ...      0.99         1
# 2238          59      Puja  ...      0.99         1
# 2239          59      Puja  ...      0.99         1
#
# [2240 rows x 6 columns]

# %%
# We can now multiply the quantity by the unit price
# and then find the total amount spent per customer:

(cust
 .merge(invoice, on='CustomerId')
 .merge(invoice_items, on='InvoiceId')
 .assign(Total=lambda df_: df_.Quantity * df_.UnitPrice)
 .groupby(['CustomerId', 'FirstName', 'LastName'])
 ['Total']
 .sum()
 .sort_values(ascending=False)
)
# Out:
# CustomerId  FirstName  LastName
# 6           Helena     Holý          49.62
# 26          Richard    Cunningham    47.62
# 57          Luis       Rojas         46.62
# 45          Ladislav   Kovács        45.62
# 46          Hugh       O'Reilly      45.62
#                                      ...
# 31          Martha     Silk          37.62
# 32          Aaron      Mitchell      37.62
# 33          Ellie      Sullivan      37.62
# 35          Madalena   Sampaio       37.62
# 59          Puja       Srivastava    36.64
# Name: Total, Length: 59, dtype: float64

# %% [markdown]
# If you are adept with SQL, you can write a SQL query as a string and pass it to the read_sql_
# query function. For example, the following will reproduce the output from step 4:

# %%
sql_string1 = '''
SELECT
NAME, 
time(avg(Milliseconds) / 100, 'unixepoch') as avg_time
FROM (
      SELECT 
      g.Name,
      t.Milliseconds
      FROM 
        genres as g
      JOIN
         tracks as t on
         g.genreid == t.genreid
)

GROUP BY Name
ORDER By avg_time

'''

# %%
pd.read_sql_query(sql_string1, engine)
# Out:
#                 Name  avg_time
# 0      Rock And Roll  00:22:26
# 1              Opera  00:29:08
# 2        Hip Hop/Rap  00:29:41
# 3     Easy Listening  00:31:31
# 4         Bossa Nova  00:36:35
# ..               ...       ...
# 20            Comedy  04:24:12
# 21          TV Shows  05:57:30
# 22             Drama  07:09:12
# 23   Science Fiction  07:17:35
# 24  Sci Fi & Fantasy  08:05:17
#
# [25 rows x 2 columns]

# %%
sql_string2 ='''
SELECT
      c.customerid,
      c.FirstName,
      c.LastName,
      sum(ii.quantity * ii.unitprice) as Total
FROM

      customers as c
      
JOIN 
     invoices as i
     on c.customerid = i.customerid
     
JOIN 
     invoice_items as ii
     on i.invoiceid = ii.invoiceid
     
GROUP BY 
     c.customerid, c.FirstName, c.LastName
     
ORDER BY
      Total desc'''

# %%
pd.read_sql_query(sql_string2, engine)
# Out:
#     CustomerId FirstName    LastName  Total
# 0            6    Helena        Holý  49.62
# 1           26   Richard  Cunningham  47.62
# 2           57      Luis       Rojas  46.62
# 3           45  Ladislav      Kovács  45.62
# 4           46      Hugh    O'Reilly  45.62
# ..         ...       ...         ...    ...
# 54          53      Phil      Hughes  37.62
# 55          54     Steve      Murray  37.62
# 56          55      Mark      Taylor  37.62
# 57          56     Diego   Gutiérrez  37.62
# 58          59      Puja  Srivastava  36.64
#
# [59 rows x 4 columns]
